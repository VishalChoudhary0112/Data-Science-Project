# %% [markdown]
# # TELECOM CHURN PREDICTION

# %% [markdown]
# ### About the dataset (Telecom Churn Data)
# 1.Customer ID: Primary key of the record
#
# 2.Churn: Detecting which customers are likely to leave a service or to cancel a subscription to a service
#
# 3.Monthly Revenue: Revenue of each Customer
#
# 4.Monthly Minutes: Number of Minutes call spoken by Customer
#
# 5.Total Recurring Charge: The Charges for the Service
#
# 6.Director Assisted Calls: When we call an operator to request a telephone number
#
# 7.Overage Minutes: Count of Call used over duration to particular post-paid cell phone plan
#
# 8.Roaming Calls: The ability to get access to the Internet when away from home at the price of a local call or at a charge considerably less than the regular long-distance charges
#
# 9.PercChangeMinutes: It indicates Percentage Change in Minutes
#
# 10.PercChangeRevenues: Percentage change in Revenue
#
# 11.Three way Calls: A way of adding a third party to your conversation without the assistance of a telephone operator
#
# 12.Dropped Calls: Count of Phone calls gets disconnected somehow from the cellular network
#
# 13.Blocked Calls: Count of Telephone call that is unable to connect to an intended recipient
#
# 14.Unanswered Calls: Count of Calling that an individual perceives but is not currently pursuing
#
# 15.Received Calls: Number of calls received by the customer
#
# 16.Out bound Calls: Call initiated by the call centre agent to customer on behalf of client to know the target customer behaviour and needs
#
# 17.Inbound Calls: In inbound calls, call-centre or customer-care receives call from customer with issues and questions
#
# 18.Peak Calls In Out: Amount of time period with fewer calls than are handled in a busy period
#
# 19.CustomerCareCalls: Customer Care Calls Attempt Count
#
# 20.OffPeakCallsInOut: Amount of time period with more calls than are handled in a busy period
#
# 21.Call Forwarding Calls: Count of Calls Forwarded by user
#
# 22.Dropped Blocked Calls: Number of VM messages customer currently has on the server
#
# 23.Call Waiting Calls: Duration of call-in waiting period
#
# 24.Months In Service: Number of months customer using service
#
# 25.Unique Subs: subscription of different networks
#
# 26.Active Subs: subscriptions of the networks that are active or in usage
#
# 27.Handset Models: Count of Handsets are used to Contact one to one
#
# 28.CurrentEquipmentDays: Number of days Current Equipment is used
#
# 29.Age HH1: User aged below 45
#
# 30.Age HH2: User aged above 45
#
# 31.Children in HH: Whether there are Children in House hold
#
# 32.Handset Refurbished: Are the handsets refurbished or not
#
# 33.Handset Web Capable: Are the handsets capable of internet connectivity
#
# 34.Truck Owner: Is the user a Truck Owner
#
# 35.RV Owner: Is the user an RV owner
#
# 36.Home Ownership: Is the house the user is staying, his own
#
# 37.Buys Visa Mail Order: Does the user buy Visa Mail order
#
# 38.Responds to Mail Offers: Does the user respond to Mail offers
#
# 39.Opt-out Mailings: Did he opt out of the mail offers sent to him
#
# 40.Non-US-Travel: Does the user travel to other countries
#
# 41.Owns-Computer: Does he have a computer or not
#
# 42.Has-Credit Card: Does he have a credit card or not
#
# 43.Retention Calls: No of Retention Calls
#
# 44.Retention Offers Accepted: Customers accepting retaining the retaining offers given by the company
#
# 45.New Cell phone User: Number of customers buying new cell phone
#
# 46.NotNewCellphoneUser: Number of customers uses exisiting cell phone
#
# 47.Referrals Made By Subscriber: Referrals made by the existing customer to the other customer
#
# 48.Income Group: SThe column talks about the customer saying to which category the customer belongs to
#
# 49.Owns Motorcycle: The columns ask about the customer weather the customer owns a motorcycle or not
#
# 50.AdjustmentsToCreditRating: Adjustments made To CreditRating
#
# 51.Handset Price: Its amount paid by the customer for his cell phone
#
# 52.MadeCallToRetentionTeam: User call to Retention in same company
#
# 53.CreditRating: Credit card user rating (out of 7)
#
# 54.PrizmCode: Grouping of region according to users
#
# 55.Occupation: Occupation of User
#
# 56.MaritalStatus: Marital Status Indicated by Yes/No/Unknown

# %%
# import 'Pandas' 
import pandas as pd 

# import 'Numpy' 
import numpy as np

# import subpackage of Matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

# import 'Seaborn' 
import seaborn as sns

# to suppress warnings 
from warnings import filterwarnings
filterwarnings('ignore')

# display all columns of the dataframe
pd.options.display.max_columns = None

# display all rows of the dataframe
pd.options.display.max_rows = 50
 
# to display the float values upto 6 decimal places     
pd.options.display.float_format = '{:.6f}'.format

# import train-test split 
from sklearn.model_selection import train_test_split

# import StandardScaler to perform scaling
from sklearn.preprocessing import StandardScaler 

# import statsmodels
import statsmodels.api as sm
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# import 'stats' package from scipy library
from scipy import stats

# import the functions to perform Chi-square tests
from scipy.stats import chi2_contingency
from scipy.stats import chi2
from scipy.stats import chisquare

# function to perform post-hoc test
import statsmodels.stats.multicomp as mc

# import function to perform post-hoc
# install scikit_posthocs using "!pip install scikit_posthocs" 
import scikit_posthocs

from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from sklearn.metrics import roc_curve
from sklearn.metrics import accuracy_score

from statsmodels.stats.outliers_influence import variance_inflation_factor

# %% [markdown]
# ## 1.DATA UNDERSTANDING AND PREPARATION

# %%
df1=pd.read_csv('cell2cell.csv')

# %%
df1.head(10)
# Out:
#    CustomerID Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0     3000002   Yes       24.000000      219.000000             22.000000
# 1     3000010   Yes       16.990000       10.000000             17.000000
# 2     3000014    No       38.000000        8.000000             38.000000
# 3     3000022    No       82.280000     1312.000000             75.000000
# 4     3000026   Yes       17.140000        0.000000             17.000000
# 5     3000030    No       38.050000      682.000000             52.000000
# 6     3000038    No       31.660000       26.000000             30.000000
# 7     3000042    No       62.130000       98.000000             66.000000
# 8     3000046    No       35.300000       24.000000             35.000000
# 9     3000050    No       81.000000     1056.000000             75.000000
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0               0.250000        0.000000      0.000000        -157.000000
# 1               0.000000        0.000000      0.000000          -4.000000
# 2               0.000000        0.000000      0.000000          -2.000000
# 3               1.240000        0.000000      0.000000         157.000000
# 4               0.000000        0.000000      0.000000           0.000000
# 5               0.250000        0.000000      0.000000         148.000000
# 6               0.250000        0.000000      0.000000          60.000000
# 7               2.480000        0.000000      0.000000          24.000000
# 8               0.000000        0.000000      0.000000          20.000000
# 9               0.000000        0.000000      0.000000          43.000000
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0          -19.000000      0.700000      0.700000         6.300000
# 1            0.000000      0.300000      0.000000         2.700000
# 2            0.000000      0.000000      0.000000         0.000000
# 3            8.100000     52.000000      7.700000        76.000000
# 4           -0.200000      0.000000      0.000000         0.000000
# 5           -3.100000      9.000000      1.700000        13.000000
# 6            4.000000      0.000000      1.000000         2.300000
# 7            6.800000      0.000000      0.300000         4.000000
# 8           -0.300000      0.000000      0.000000         1.000000
# 9            2.400000      0.000000      0.000000         0.000000
#
#    CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0           0.000000       0.000000      97.200000       0.000000
# 1           0.000000       0.000000       0.000000       0.000000
# 2           0.000000       0.000000       0.400000       0.300000
# 3           4.300000       1.300000     200.300000     370.300000
# 4           0.000000       0.000000       0.000000       0.000000
# 5           0.700000       0.000000      42.200000       6.700000
# 6           0.000000       0.000000       0.000000       0.000000
# 7           4.000000       0.000000       0.000000       3.700000
# 8           0.000000       0.000000       2.400000       4.000000
# 9           0.000000       0.000000       0.000000       0.000000
#
#    InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0      0.000000       58.000000          24.000000             1.300000
# 1      0.000000        5.000000           1.000000             0.300000
# 2      0.000000        1.300000           3.700000             0.000000
# 3    147.000000      555.700000         303.700000            59.700000
# 4      0.000000        0.000000           0.000000             0.000000
# 5      0.000000       33.300000          53.000000            10.700000
# 6      0.000000        1.700000           1.700000             1.000000
# 7      0.000000        7.700000           7.300000             0.300000
# 8      1.700000        9.300000           1.700000             0.000000
# 9      0.000000        0.000000           0.000000             0.000000
#
#    CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0             0.000000          0.300000               61           2
# 1             0.000000          0.000000               58           1
# 2             0.000000          0.000000               60           1
# 3             0.000000         22.700000               59           2
# 4             0.000000          0.000000               53           2
# 5             0.000000          0.700000               53           1
# 6             0.000000          0.000000               57           2
# 7             0.000000          0.000000               59           2
# 8             0.000000          0.000000               53           3
# 9             0.000000          0.000000               55           1
#
#    ActiveSubs ServiceArea  Handsets  HandsetModels  CurrentEquipmentDays  \
# 0           1   SEAPOR503  2.000000       2.000000            361.000000
# 1           1   PITHOM412  2.000000       1.000000           1504.000000
# 2           1   MILMIL414  1.000000       1.000000           1812.000000
# 3           2   PITHOM412  9.000000       4.000000            458.000000
# 4           2   OKCTUL918  4.000000       3.000000            852.000000
# 5           1   OKCTUL918  3.000000       2.000000            231.000000
# 6           2   OKCTUL918  2.000000       2.000000            601.000000
# 7           2   OKCOKC405  3.000000       3.000000            464.000000
# 8           3   SANMCA210  4.000000       3.000000            544.000000
# 9           1   PITHOM412  9.000000       5.000000            388.000000
#
#      AgeHH1    AgeHH2 ChildrenInHH HandsetRefurbished HandsetWebCapable  \
# 0 62.000000  0.000000           No                 No               Yes
# 1 40.000000 42.000000          Yes                 No                No
# 2 26.000000 26.000000          Yes                 No                No
# 3 30.000000  0.000000           No                 No               Yes
# 4 46.000000 54.000000           No                 No                No
# 5 28.000000  0.000000           No                 No               Yes
# 6 52.000000 58.000000           No                 No               Yes
# 7 46.000000 46.000000          Yes                 No               Yes
# 8 36.000000 34.000000          Yes                 No               Yes
# 9 46.000000 68.000000           No                 No               Yes
#
#   TruckOwner RVOwner Homeownership BuysViaMailOrder RespondsToMailOffers  \
# 0         No      No         Known              Yes                  Yes
# 1         No      No         Known              Yes                  Yes
# 2         No      No       Unknown               No                   No
# 3         No      No         Known              Yes                  Yes
# 4         No      No         Known              Yes                  Yes
# 5         No      No         Known               No                   No
# 6         No      No         Known              Yes                  Yes
# 7         No      No         Known              Yes                  Yes
# 8         No      No         Known               No                   No
# 9         No      No         Known               No                   No
#
#   OptOutMailings NonUSTravel OwnsComputer HasCreditCard  RetentionCalls  \
# 0             No          No          Yes           Yes               1
# 1             No          No          Yes           Yes               0
# 2             No          No           No           Yes               0
# 3             No          No           No           Yes               0
# 4             No          No          Yes           Yes               0
# 5             No         Yes           No           Yes               0
# 6             No         Yes           No           Yes               0
# 7             No          No           No           Yes               0
# 8             No          No           No           Yes               0
# 9             No          No          Yes           Yes               0
#
#    RetentionOffersAccepted NewCellphoneUser NotNewCellphoneUser  \
# 0                        0               No                  No
# 1                        0              Yes                  No
# 2                        0              Yes                  No
# 3                        0              Yes                  No
# 4                        0               No                 Yes
# 5                        0              Yes                  No
# 6                        0               No                 Yes
# 7                        0              Yes                  No
# 8                        0              Yes                  No
# 9                        0              Yes                  No
#
#    ReferralsMadeBySubscriber  IncomeGroup OwnsMotorcycle  \
# 0                          0            4             No
# 1                          0            5             No
# 2                          0            6             No
# 3                          0            6             No
# 4                          0            9             No
# 5                          0            1             No
# 6                          0            9             No
# 7                          0            6             No
# 8                          0            9             No
# 9                          0            5             No
#
#    AdjustmentsToCreditRating HandsetPrice MadeCallToRetentionTeam  \
# 0                          0           30                     Yes
# 1                          0           30                      No
# 2                          0      Unknown                      No
# 3                          0           10                      No
# 4                          1           10                      No
# 5                          1           30                      No
# 6                          1           30                      No
# 7                          0           30                      No
# 8                          0           80                      No
# 9                          1           30                      No
#
#   CreditRating PrizmCode    Occupation MaritalStatus
# 0    1-Highest  Suburban  Professional            No
# 1     4-Medium  Suburban  Professional           Yes
# 2       3-Good      Town        Crafts           Yes
# 3     4-Medium     Other         Other            No
# 4    1-Highest     Other  Professional           Yes
# 5       3-Good     Other         Other           Yes
# 6    1-Highest     Other          Self           Yes
# 7    1-Highest     Other  Professional            No
# 8    1-Highest     Other         Other           Yes
# 9       3-Good     Other  Professional            No

# %%
df1['CustomerID'].nunique()
# Out:
# 51047

# %%
# since customer id is unique for each customer we are dropping this column.

# %%
df1.drop(columns=['CustomerID'],inplace=True)

# %%
df1.shape
# Out:
# (51047, 57)

# %%
 for i in df1.columns:
    if df1[i].dtype == 'object':
        print('COLUMN NAME: ',i)
        print()
        print('NO OF UNIQUE CLASSES: ',df1[i].nunique())
        print()
        print(df1[i].describe())
        print()
# Out:
# COLUMN NAME:  Churn
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      36336
# Name: Churn, dtype: object
#
# COLUMN NAME:  ServiceArea
#
# NO OF UNIQUE CLASSES:  747
#
# count         51023
# unique          747
# top       NYCBRO917
# freq           1684
# Name: ServiceArea, dtype: object
#
# COLUMN NAME:  ChildrenInHH
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      38679
# Name: ChildrenInHH, dtype: object
#
# COLUMN NAME:  HandsetRefurbished
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      43956
# Name: HandsetRefurbished, dtype: object
#
# COLUMN NAME:  HandsetWebCapable
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top         Yes
# freq      46046
# Name: HandsetWebCapable, dtype: object
#
# COLUMN NAME:  TruckOwner
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      41524
# Name: TruckOwner, dtype: object
#
# COLUMN NAME:  RVOwner
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      46894
# Name: RVOwner, dtype: object
#
# COLUMN NAME:  Homeownership
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top       Known
# freq      33987
# Name: Homeownership, dtype: object
#
# COLUMN NAME:  BuysViaMailOrder
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      32596
# Name: BuysViaMailOrder, dtype: object
#
# COLUMN NAME:  RespondsToMailOffers
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      31821
# Name: RespondsToMailOffers, dtype: object
#
# COLUMN NAME:  OptOutMailings
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      50295
# Name: OptOutMailings, dtype: object
#
# COLUMN NAME:  NonUSTravel
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      48168
# Name: NonUSTravel, dtype: object
#
# COLUMN NAME:  OwnsComputer
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      41583
# Name: OwnsComputer, dtype: object
#
# COLUMN NAME:  HasCreditCard
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top         Yes
# freq      34503
# Name: HasCreditCard, dtype: object
#
# COLUMN NAME:  NewCellphoneUser
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      41223
# Name: NewCellphoneUser, dtype: object
#
# COLUMN NAME:  NotNewCellphoneUser
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      44012
# Name: NotNewCellphoneUser, dtype: object
#
# COLUMN NAME:  OwnsMotorcycle
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      50368
# Name: OwnsMotorcycle, dtype: object
#
# COLUMN NAME:  HandsetPrice
#
# NO OF UNIQUE CLASSES:  16
#
# count       51047
# unique         16
# top       Unknown
# freq        28982
# Name: HandsetPrice, dtype: object
#
# COLUMN NAME:  MadeCallToRetentionTeam
#
# NO OF UNIQUE CLASSES:  2
#
# count     51047
# unique        2
# top          No
# freq      49302
# Name: MadeCallToRetentionTeam, dtype: object
#
# COLUMN NAME:  CreditRating
#
# NO OF UNIQUE CLASSES:  7
#
# count      51047
# unique         7
# top       2-High
# freq       18993
# Name: CreditRating, dtype: object
#
# COLUMN NAME:  PrizmCode
#
# NO OF UNIQUE CLASSES:  4
#
# count     51047
# unique        4
# top       Other
# freq      24655
# Name: PrizmCode, dtype: object
#
# COLUMN NAME:  Occupation
#
# NO OF UNIQUE CLASSES:  8
#
# count     51047
# unique        8
# top       Other
# freq      37637
# Name: Occupation, dtype: object
#
# COLUMN NAME:  MaritalStatus
#
# NO OF UNIQUE CLASSES:  3
#
# count       51047
# unique          3
# top       Unknown
# freq        19700
# Name: MaritalStatus, dtype: object

# %%
# as we can see newcellphoneuser and not newcellphone user is redundant column
df1=df1.drop(columns=['NotNewCellphoneUser'])

# %%
plt.rcParams['figure.figsize']=[30,18]
sns.heatmap(df1.corr(),annot=True)
# Out:
# <AxesSubplot: >

# %% [markdown]
# from the above plot we come to know that "MonthlyMinutes" and "MonthlyRevenue" have high co relation 0.83.

# %%
plt.rcParams['figure.figsize']=[20,8]
sns.scatterplot(x="MonthlyRevenue", y="MonthlyMinutes",hue='Churn', data=df1)
# Out:
# <AxesSubplot: xlabel='MonthlyRevenue', ylabel='MonthlyMinutes'>

# %% [markdown]
# In the  scatter plot the points are more overlapping,it means non-linear model gives better results compare to linear model for this data.

# %% [markdown]
# ### Treating the Handset and Handsetmodels variables

# %%
df1[['Handsets','HandsetModels']]
# Out:
#        Handsets  HandsetModels
# 0      2.000000       2.000000
# 1      2.000000       1.000000
# 2      1.000000       1.000000
# 3      9.000000       4.000000
# 4      4.000000       3.000000
# ...         ...            ...
# 51042  2.000000       2.000000
# 51043  2.000000       2.000000
# 51044  3.000000       2.000000
# 51045  2.000000       2.000000
# 51046  7.000000       5.000000
#
# [51047 rows x 2 columns]

# %%
df1['Handsets'].unique()
# Out:
# array([ 2.,  1.,  9.,  4.,  3., 10.,  5.,  8., 18.,  7.,  6., 24., 12.,
#        11., 14., 13., 17., 16., 21., 19., 15., 22., 20., nan])

# %%
df1['HandsetModels'].unique()
# Out:
# array([ 2.,  1.,  4.,  3.,  5.,  6.,  9.,  7., 10.,  8., 11., 15., 14.,
#        nan])

# %%
df1.dropna(subset=['HandsetModels'],inplace=True)

# %%
# perorming stastical test on these two variable.

# %%
from statsmodels.stats import weightstats as stests

# %%
x=df1['Handsets'][df1['Churn']=='Yes']
y=df1['Handsets'][df1['Churn']=='No']

# %%
t_stat, p_val = stats.ttest_ind(a =x, b =y)

# print the test statistic value and corresponding p-value
print('Test Statistic:', t_stat)
print('p-value:', p_val)
# Out:
# Test Statistic: -7.424760622989963
# p-value: 1.147385066838404e-13

# %%
# we come to know that the means of two samples are different .

# %% [markdown]
# Perfroming t-test for handsetmodels column.

# %%
x=df1['HandsetModels'][df1['Churn']=='Yes']
y=df1['HandsetModels'][df1['Churn']=='No']

# %%
t_stat, p_val = stats.ttest_ind(a =x, b =y)

# print the test statistic value and corresponding p-value
print('Test Statistic:', t_stat)
print('p-value:', p_val)
# Out:
# Test Statistic: -9.055165161881412
# p-value: 1.4103382551702694e-19

# %%
# since p-val is almost equal to zero hence two samples have different menas.

# %% [markdown]
# Conclusion:
# * The statistical test shows both the columns are contributing to the target,hence we cannot drop any of them.

# %% [markdown]
# ### Treating service area categorical variable.

# %%
df1['ServiceArea']
# Out:
# 0        SEAPOR503
# 1        PITHOM412
# 2        MILMIL414
# 3        PITHOM412
# 4        OKCTUL918
#            ...
# 51042    LAXSFN818
# 51043    LAXCDG310
# 51044    LAXCDG310
# 51045    NEVPOW619
# 51046    NEVPOW619
# Name: ServiceArea, Length: 51046, dtype: object

# %%
df1['ServiceArea'].nunique()
# Out:
# 747

# %%
# since we have 747 unique values in ServiceArea variable.
# check for the alternate variable which resembles the service region in dataset.

# %%
df1['PrizmCode'].unique()
# Out:
# array(['Suburban', 'Town', 'Other', 'Rural'], dtype=object)

# %%
# we have Prizmcode variable which is alternate to the service area, so we can drop the servicearea
#   considering it as redundant variable.

# %%
# dropping the redundant column serviceArea.
df1.drop(columns='ServiceArea',inplace=True)

# %% [markdown]
# ### treating Handset price variable

# %%
df1['HandsetPrice'].unique()
# Out:
# array(['30', 'Unknown', '10', '80', '150', '300', '40', '200', '100',
#        '130', '60', '400', '240', '250', '180', '500'], dtype=object)

# %%
df1[df1['HandsetPrice']=='Unknown'].shape[0]
# Out:
# 28981

# %%
# replacing unknown with zeros
df1['HandsetPrice']=df1['HandsetPrice'].replace(to_replace='Unknown',value= 0)

# %%
df1['HandsetPrice']=df1['HandsetPrice'].replace(to_replace=0,value= np.nan)

# %%
# calculating null value percentage for Handsetprice variable
df1['HandsetPrice'].isnull().sum()/df1.shape[0]*100
# Out:
# 56.7742820201387

# %%
# as we can see that we have more than 56% of null values , 
# hence we are dropping the column,instead of filling 56% values which are not true.

# %%
df1.drop(columns='HandsetPrice',inplace=True)

# %%
df1.shape
# Out:
# (51046, 54)

# %% [markdown]
# ### Treating credit rating variable

# %%
df1['CreditRating'].unique()
# Out:
# array(['1-Highest', '4-Medium', '3-Good', '6-VeryLow', '2-High', '5-Low',
#        '7-Lowest'], dtype=object)

# %%
# binning the variable with high,medium and low

# %%
dict_rating={ '1-Highest':'High',
       '2-High':'High',
       '3-Good':'Medium',
       '4-Medium':'Medium',
       '5-Low':'Low',
       '6-VeryLow':'Low',
       '7-Lowest':'Low'
        }

# %%
df1['CreditRating']=df1['CreditRating'].map(dict_rating)

# %%
df1['CreditRating'].unique()
# Out:
# array(['High', 'Medium', 'Low'], dtype=object)

# %%
# now we have only 3 categories high , medium and low

# %%
### categorical variables

# %%
cat=df1.select_dtypes(include='object').columns

# %%
print(cat, 'number of categorical columns are' ,len(cat))
# Out:
# Index(['Churn', 'ChildrenInHH', 'HandsetRefurbished', 'HandsetWebCapable',
#        'TruckOwner', 'RVOwner', 'Homeownership', 'BuysViaMailOrder',
#        'RespondsToMailOffers', 'OptOutMailings', 'NonUSTravel', 'OwnsComputer',
#        'HasCreditCard', 'NewCellphoneUser', 'OwnsMotorcycle',
#        'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
#        'MaritalStatus'],
#       dtype='object') number of categorical columns are 20

# %%
# numerical variables

# %%
nume=df1.select_dtypes(include=np.number).columns

# %%
print(nume,
      'number of numerical columns are' ,len(nume))
# Out:
# Index(['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge',
#        'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls',
#        'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls',
#        'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 'ThreewayCalls',
#        'ReceivedCalls', 'OutboundCalls', 'InboundCalls', 'PeakCallsInOut',
#        'OffPeakCallsInOut', 'DroppedBlockedCalls', 'CallForwardingCalls',
#        'CallWaitingCalls', 'MonthsInService', 'UniqueSubs', 'ActiveSubs',
#        'Handsets', 'HandsetModels', 'CurrentEquipmentDays', 'AgeHH1', 'AgeHH2',
#        'RetentionCalls', 'RetentionOffersAccepted',
#        'ReferralsMadeBySubscriber', 'IncomeGroup',
#        'AdjustmentsToCreditRating'],
#       dtype='object') number of numerical columns are 34

# %%
plt.rcParams['figure.figsize']=[15,60]
n=1
for i in nume:
    plt.subplot(12,3,n)
    sns.boxplot(x='Churn',y=i,data=df1)
    n+=1
    plt.xticks(rotation=90)
plt.show()

# %%
df1.describe().T
# Out:
#                                  count       mean        std          min  \
# MonthlyRevenue            50890.000000  58.834136  44.507700    -6.170000
# MonthlyMinutes            50890.000000 525.663745 529.871145     0.000000
# TotalRecurringCharge      50890.000000  46.829298  23.848440   -11.000000
# DirectorAssistedCalls     50890.000000   0.895247   2.228564     0.000000
# OverageMinutes            50890.000000  40.028571  96.588862     0.000000
# RoamingCalls              50890.000000   1.236268   9.818389     0.000000
# PercChangeMinutes         50679.000000 -11.548136 257.517308 -3875.000000
# PercChangeRevenues        50679.000000  -1.192009  39.575305 -1107.700000
# DroppedCalls              51046.000000   6.011607   9.044005     0.000000
# BlockedCalls              51046.000000   4.085752  10.946997     0.000000
# UnansweredCalls           51046.000000  28.289535  38.876373     0.000000
# CustomerCareCalls         51046.000000   1.869036   5.096181     0.000000
# ThreewayCalls             51046.000000   0.298844   1.168287     0.000000
# ReceivedCalls             51046.000000 114.802370 166.486752     0.000000
# OutboundCalls             51046.000000  25.378212  35.209312     0.000000
# InboundCalls              51046.000000   8.178265  16.666002     0.000000
# PeakCallsInOut            51046.000000  90.551289 104.947733     0.000000
# OffPeakCallsInOut         51046.000000  67.652116  92.753124     0.000000
# DroppedBlockedCalls       51046.000000  10.158202  15.555371     0.000000
# CallForwardingCalls       51046.000000   0.012277   0.594174     0.000000
# CallWaitingCalls          51046.000000   1.840540   5.585178     0.000000
# MonthsInService           51046.000000  18.756377   9.800200     6.000000
# UniqueSubs                51046.000000   1.532167   1.223394     1.000000
# ActiveSubs                51046.000000   1.354347   0.675481     0.000000
# Handsets                  51046.000000   1.805646   1.331173     1.000000
# HandsetModels             51046.000000   1.558751   0.905932     1.000000
# CurrentEquipmentDays      51046.000000 380.545841 253.801982    -5.000000
# AgeHH1                    50137.000000  31.338752  22.094412     0.000000
# AgeHH2                    50137.000000  21.144564  23.931420     0.000000
# RetentionCalls            51046.000000   0.037202   0.206485     0.000000
# RetentionOffersAccepted   51046.000000   0.018278   0.142460     0.000000
# ReferralsMadeBySubscriber 51046.000000   0.052071   0.307595     0.000000
# IncomeGroup               51046.000000   4.324609   3.138209     0.000000
# AdjustmentsToCreditRating 51046.000000   0.053912   0.383151     0.000000
#
#                                  25%        50%        75%         max
# MonthlyRevenue             33.610000  48.460000  71.060000 1223.380000
# MonthlyMinutes            158.000000 366.000000 723.000000 7359.000000
# TotalRecurringCharge       30.000000  45.000000  60.000000  400.000000
# DirectorAssistedCalls       0.000000   0.250000   0.990000  159.390000
# OverageMinutes              0.000000   3.000000  41.000000 4321.000000
# RoamingCalls                0.000000   0.000000   0.300000 1112.400000
# PercChangeMinutes         -83.000000  -5.000000  66.000000 5192.000000
# PercChangeRevenues         -7.100000  -0.300000   1.600000 2483.500000
# DroppedCalls                0.700000   3.000000   7.700000  221.700000
# BlockedCalls                0.000000   1.000000   3.700000  384.300000
# UnansweredCalls             5.300000  16.300000  36.300000  848.700000
# CustomerCareCalls           0.000000   0.000000   1.700000  327.300000
# ThreewayCalls               0.000000   0.000000   0.300000   66.000000
# ReceivedCalls               8.300000  52.800000 153.500000 2692.400000
# OutboundCalls               3.300000  13.700000  34.000000  644.300000
# InboundCalls                0.000000   2.000000   9.300000  519.300000
# PeakCallsInOut             23.000000  62.000000 121.300000 2090.700000
# OffPeakCallsInOut          11.000000  35.700000  88.700000 1474.700000
# DroppedBlockedCalls         1.700000   5.300000  12.300000  411.700000
# CallForwardingCalls         0.000000   0.000000   0.000000   81.300000
# CallWaitingCalls            0.000000   0.300000   1.300000  212.700000
# MonthsInService            11.000000  16.000000  24.000000   61.000000
# UniqueSubs                  1.000000   1.000000   2.000000  196.000000
# ActiveSubs                  1.000000   1.000000   2.000000   53.000000
# Handsets                    1.000000   1.000000   2.000000   24.000000
# HandsetModels               1.000000   1.000000   2.000000   15.000000
# CurrentEquipmentDays      205.000000 329.000000 515.000000 1812.000000
# AgeHH1                      0.000000  36.000000  48.000000   99.000000
# AgeHH2                      0.000000   0.000000  42.000000   99.000000
# RetentionCalls              0.000000   0.000000   0.000000    4.000000
# RetentionOffersAccepted     0.000000   0.000000   0.000000    3.000000
# ReferralsMadeBySubscriber   0.000000   0.000000   0.000000   35.000000
# IncomeGroup                 0.000000   5.000000   7.000000    9.000000
# AdjustmentsToCreditRating   0.000000   0.000000   0.000000   25.000000

# %% [markdown]
# # 2.DATA CLEANING

# %%
# making copy of original data set
df=df1.copy()

# %% [markdown]
# ### 2.1 Duplicate values

# %%
print(df1.duplicated().sum())
print(' ')
print(f'Dataset have {df1.duplicated().sum()} duplicate values.')
# Out:
# 0
#
# Dataset have 0 duplicate values.

# %%
# there are no duplicate values

# %%
# AgeHH1 and AgeHH2 has highest null values in the data.

# %% [markdown]
# ### Treating numerical columns AgeHH1 and AgeHH2

# %%
age_cols=['AgeHH1','AgeHH2']
plt.rcParams['figure.figsize']=[20,8]
rows=1
columns=2
iterator=1
for i in age_cols:
    plt.subplot(rows,columns,iterator)
    sns.countplot(df1.loc[:,i])
    iterator=iterator+1
    plt.xticks(rotation=90)
plt.tight_layout()    
plt.show()

# %%
# from graph we can see that there are maximum number of zero values

# %%
df1[df1['AgeHH1']==0].shape
# Out:
# (13916, 54)

# %%
df1[df1['AgeHH2']==0].shape
# Out:
# (26086, 54)

# %%
# from the graph we can observe that the age columns 'AgeHH2' is having same distribution as AgeHH1,
# since the ageHH2 having more zero values the distribution is lower compare to ageHH1.

# %%
sns.heatmap(df1[['AgeHH1','AgeHH2']].corr(),annot=True)
# Out:
# <AxesSubplot: >

# %%
# we are combining both the age columns because they are redundant.

# %%
x=df1['AgeHH1'].to_list()

# %%
y=df1['AgeHH2'].to_list()

# %%
# defining function to combine the age columns.
def age(x,y):
    s=[]    
    for x,y in zip(x,y):
        if x==0 and y==0:
             s.append(float(0))
        elif x!=0 and y!=0:
             s.append((x+y)//2)
        elif x==0 and y!=0 :
             s.append(y)
        elif y==0 and x!=0:
             s.append(x)
        
    return s

# %%
x=age(x,y)

# %%
x.count(0)
# Out:
# 13916

# %%
# creating new combined column called 'Age'
df1['Age']=x

# %%
# comparing the new column with old age columns to cross verify.
df1[['AgeHH1','AgeHH2','Age']]
# Out:
#          AgeHH1    AgeHH2       Age
# 0     62.000000  0.000000 62.000000
# 1     40.000000 42.000000 41.000000
# 2     26.000000 26.000000 26.000000
# 3     30.000000  0.000000 30.000000
# 4     46.000000 54.000000 50.000000
# ...         ...       ...       ...
# 51042 68.000000 64.000000 66.000000
# 51043 48.000000 48.000000 48.000000
# 51044 36.000000  0.000000 36.000000
# 51045 32.000000  0.000000 32.000000
# 51046  0.000000  0.000000  0.000000
#
# [51046 rows x 3 columns]

# %%
# comparign the Agehh1 and new age column.

# %%
plt.rcParams['figure.figsize']=[4,4]
sns.heatmap(df1[['AgeHH1','Age']].corr(),annot=True,cmap='spring')
# Out:
# <AxesSubplot: >

# %% [markdown]
# conclusion:
# * from the corelation we can AgeHH1 and AgeHH2 are  showing 99% correlation.
# * lets drop the redundant age columns agehh1 and agehh2 while having age column with in the data.

# %%
df1.drop(columns=['AgeHH1','AgeHH2'],inplace=True)

# %%
df1.shape
# Out:
# (51046, 53)

# %% [markdown]
# ### Treating new age variable

# %%
df1['Age'].isnull().sum()
# Out:
# 909

# %%
df1[df1['Age']==0].shape[0]
# Out:
# 13916

# %%
# we have to treat zeros as null

# %%
df1['Age'].fillna(value=0,inplace=True)

# %%
df1[df1['Age']==0].shape[0]/df1.shape[0]*100
# Out:
# 29.042432315950318

# %%
x=df1['Age'][(df1['Age']==0)&(df1['Churn']=='Yes')]
x.count()
# Out:
# 4455

# %%
y=df1['Age'][(df1['Age']==0)&(df1['Churn']=='No')]
y.count()
# Out:
# 10370

# %%
a=df1['Age'][(df1['Age']!=0)&(df1['Churn']=='Yes')]

# %%
a.count()
# Out:
# 10256

# %%
b=df1['Age'][(df1['Age']!=0)&(df1['Churn']=='No')]

# %%
b.count()
# Out:
# 25965

# %%
t_stat, p_val = stats.ttest_ind(a,b)

# print the test statistic value and corresponding p-value
print('Test Statistic:', t_stat)
print('p-value:', p_val)
# Out:
# Test Statistic: -6.542884052576937
# p-value: 6.114693381777893e-11

# %% [markdown]
# * by the statistical test we know that two means are not equal.

# %%
# converting zeros to null.
df1['Age']=df1['Age'].replace(to_replace=0,value=np.nan)

# %% [markdown]
# ## Treating Null values

# %%
# checking for missing values
n=pd.Series(df1.isnull().sum()[df1.isnull().sum()!=0])
n
# Out:
# MonthlyRevenue             156
# MonthlyMinutes             156
# TotalRecurringCharge       156
# DirectorAssistedCalls      156
# OverageMinutes             156
# RoamingCalls               156
# PercChangeMinutes          367
# PercChangeRevenues         367
# Age                      14825
# dtype: int64

# %%
# calculating percentage of null values.
n/df1.shape[0]*100
# Out:
# MonthlyRevenue           0.305607
# MonthlyMinutes           0.305607
# TotalRecurringCharge     0.305607
# DirectorAssistedCalls    0.305607
# OverageMinutes           0.305607
# RoamingCalls             0.305607
# PercChangeMinutes        0.718959
# PercChangeRevenues       0.718959
# Age                     29.042432
# dtype: float64

# %% [markdown]
# ### dropping the rows which contain null values less than 1%.

# %%
drop_cols=['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge',
       'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls','PercChangeMinutes','PercChangeRevenues']

# %%
df1.dropna(subset=drop_cols,inplace=True)

# %%
df1.isnull().sum()[df1.isnull().sum()!=0]
# Out:
# Age    14712
# dtype: int64

# %%
df1=df1.reset_index(drop=True,)

# %%
df1.shape
# Out:
# (50679, 53)

# %%
num_cols=df1.select_dtypes(include=np.number)
num_cols.columns
# Out:
# Index(['MonthlyRevenue', 'MonthlyMinutes', 'TotalRecurringCharge',
#        'DirectorAssistedCalls', 'OverageMinutes', 'RoamingCalls',
#        'PercChangeMinutes', 'PercChangeRevenues', 'DroppedCalls',
#        'BlockedCalls', 'UnansweredCalls', 'CustomerCareCalls', 'ThreewayCalls',
#        'ReceivedCalls', 'OutboundCalls', 'InboundCalls', 'PeakCallsInOut',
#        'OffPeakCallsInOut', 'DroppedBlockedCalls', 'CallForwardingCalls',
#        'CallWaitingCalls', 'MonthsInService', 'UniqueSubs', 'ActiveSubs',
#        'Handsets', 'HandsetModels', 'CurrentEquipmentDays', 'RetentionCalls',
#        'RetentionOffersAccepted', 'ReferralsMadeBySubscriber', 'IncomeGroup',
#        'AdjustmentsToCreditRating', 'Age'],
#       dtype='object')

# %% [markdown]
# ### Imputing null values in age column using KNN Imputers

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import StandardScaler
ss=StandardScaler()
num_scaled=ss.fit_transform(num_cols)

# %%
imputer=KNNImputer(n_neighbors=1000)
df_filled=imputer.fit_transform(num_scaled)

# %%
df_filled=pd.DataFrame(df_filled,columns=num_cols.columns)
df_filled
# Out:
#        MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0           -0.783843       -0.580074             -1.045645
# 1           -0.941334       -0.974398             -1.255508
# 2           -0.469311       -0.978171             -0.374082
# 3            0.525509        1.482105              1.178906
# 4           -0.937964       -0.993265             -1.255508
# ...               ...             ...                   ...
# 50674       -0.605908       -0.874402             -1.255508
# 50675       -0.199712       -0.065001              0.129589
# 50676        0.294328        0.372717              0.969042
# 50677        1.316557       -0.268766             -0.709864
# 50678        0.815103        2.299053              1.598632
#
#        DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0                  -0.289834       -0.414232     -0.125819          -0.564829
# 1                  -0.401835       -0.414232     -0.125819           0.029311
# 2                  -0.401835       -0.414232     -0.125819           0.037078
# 3                   0.153688       -0.414232     -0.125819           0.654518
# 4                  -0.401835       -0.414232     -0.125819           0.044845
# ...                      ...             ...           ...                ...
# 50674              -0.401835        0.030554     -0.125819          -0.102720
# 50675              -0.401835       -0.414232     -0.125819           0.044845
# 50676              -0.401835       -0.372857     -0.034137          -0.110486
# 50677              -0.401835        2.171737     -0.125819           0.044845
# 50678               0.041687        0.051242      0.352965           0.518604
#
#        PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0               -0.449982     -0.588732     -0.310138        -0.567148
# 1                0.030120     -0.632953     -0.373953        -0.659648
# 2                0.030120     -0.666120     -0.373953        -0.729024
# 3                0.234795      5.082715      0.328017         1.223762
# 4                0.025067     -0.666120     -0.373953        -0.729024
# ...                   ...           ...           ...              ...
# 50674           -0.303424     -0.588732     -0.373953        -0.505481
# 50675            0.030120     -0.257068     -0.346604         0.357856
# 50676           -0.020417      0.914810     -0.282788        -0.130341
# 50677            0.030120     -0.223902     -0.282788        -0.035271
# 50678            0.431890      1.180141     -0.310138         0.332161
#
#        CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0              -0.367182      -0.256169      -0.107761      -0.723013
# 1              -0.367182      -0.256169      -0.691072      -0.723013
# 2              -0.367182      -0.256169      -0.688671      -0.714491
# 3               0.474745       0.855308       0.510956       9.795865
# 4              -0.367182      -0.256169      -0.691072      -0.723013
# ...                  ...            ...            ...            ...
# 50674          -0.367182      -0.256169      -0.607056      -0.723013
# 50675          -0.308443      -0.256169      -0.646063      -0.532690
# 50676          -0.367182       1.197301      -0.269792       0.007031
# 50677          -0.367182      -0.256169      -0.560847      -0.686085
# 50678          -0.367182      -0.256169       3.398702       1.825038
#
#        InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0         -0.491577       -0.312753          -0.472485            -0.570786
# 1         -0.491577       -0.817997          -0.720326            -0.635004
# 2         -0.491577       -0.853269          -0.691232            -0.654269
# 3          8.311225        4.431774           2.541478             3.179537
# 4         -0.491577       -0.865662          -0.731102            -0.654269
# ...             ...             ...                ...                  ...
# 50674     -0.491577       -0.713135          -0.572699            -0.609317
# 50675     -0.491577       -0.405223          -0.523131            -0.397398
# 50676     -0.473612        1.631959          -0.594251             0.328264
# 50677     -0.491577        0.080956          -0.145982            -0.333180
# 50678      1.502527        2.172475           1.944504             0.456700
#
#        CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0                -0.020737         -0.276289         4.339230    0.382345
# 1                -0.020737         -0.329856         4.031488   -0.433489
# 2                -0.020737         -0.329856         4.236649   -0.433489
# 3                -0.020737          3.723433         4.134069    0.382345
# 4                -0.020737         -0.329856         3.518585    0.382345
# ...                    ...               ...              ...         ...
# 50674            -0.020737         -0.276289         1.159231   -0.433489
# 50675            -0.020737         -0.276289         1.159231   -0.433489
# 50676            -0.020737         -0.204865         1.159231   -0.433489
# 50677            -0.020737         -0.329856         1.159231   -0.433489
# 50678            -0.020737          2.223538         1.056650   -0.433489
#
#        ActiveSubs  Handsets  HandsetModels  CurrentEquipmentDays  \
# 0       -0.523532  0.146580       0.487141             -0.072301
# 1       -0.523532  0.146580      -0.616471              4.462720
# 2       -0.523532 -0.604989      -0.616471              5.684756
# 3        0.956226  5.407560       2.694365              0.312561
# 4        0.956226  1.649717       1.590753              1.875814
# ...           ...       ...            ...                   ...
# 50674   -0.523532 -0.604989      -0.616471              1.998811
# 50675   -0.523532 -0.604989      -0.616471              1.994844
# 50676   -0.523532 -0.604989      -0.616471              1.994844
# 50677   -0.523532  0.146580       0.487141              0.435558
# 50678   -0.523532  0.146580       0.487141              0.336367
#
#        RetentionCalls  RetentionOffersAccepted  ReferralsMadeBySubscriber  \
# 0            4.784978                -0.127989                  -0.169323
# 1           -0.175702                -0.127989                  -0.169323
# 2           -0.175702                -0.127989                  -0.169323
# 3           -0.175702                -0.127989                  -0.169323
# 4           -0.175702                -0.127989                  -0.169323
# ...               ...                      ...                        ...
# 50674       -0.175702                -0.127989                  -0.169323
# 50675       -0.175702                -0.127989                  -0.169323
# 50676       -0.175702                -0.127989                  -0.169323
# 50677       -0.175702                -0.127989                  -0.169323
# 50678       -0.175702                -0.127989                  -0.169323
#
#        IncomeGroup  AdjustmentsToCreditRating       Age
# 0        -0.103552                  -0.140245  1.587335
# 1         0.215218                  -0.140245 -0.144763
# 2         0.533989                  -0.140245 -1.381975
# 3         0.533989                  -0.140245 -1.052052
# 4         1.490301                   2.476643  0.597565
# ...            ...                        ...       ...
# 50674    -0.422323                  -0.140245  1.257411
# 50675    -1.378634                  -0.140245  0.146065
# 50676     0.852760                  -0.140245  1.009969
# 50677    -0.741093                  -0.140245 -1.711899
# 50678     1.490301                   2.476643  0.432603
#
# [50679 rows x 33 columns]

# %%
num_scaled=df_filled

# %%
scaled_cols=num_scaled.columns

# %% [markdown]
# ### Imputing null values in MaritalStatus using KNN Classifier

# %%
df1['MaritalStatus'].value_counts()
# Out:
# Unknown    19556
# Yes        18520
# No         12603
# Name: MaritalStatus, dtype: int64

# %%
dict_1={'Unknown':np.nan,'Yes':1,'No':0 }

# %%
mar=df1['MaritalStatus']

# %%
mar=mar.map(dict_1)

# %%
mar.isnull().sum()
# Out:
# 19556

# %%
df_mar=pd.concat([num_scaled,mar],axis=1)

# %%
x_train = df_mar[scaled_cols][~(df_mar['MaritalStatus'].isnull()==True)]

# %%
x_train.shape
# Out:
# (31123, 33)

# %%
y_train=df_mar['MaritalStatus'][~(df_mar['MaritalStatus'].isnull()==True)]

# %%
y_train.shape
# Out:
# (31123,)

# %%
x_test= df_mar[scaled_cols][(df_mar['MaritalStatus'].isnull()==True)]

# %%
x_test.shape
# Out:
# (19556, 33)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)

# %%
y_pred.shape
# Out:
# (19556,)

# %%
index_list=df_mar[df_mar['MaritalStatus'].isnull()==True].index

# %%
df_mar['MaritalStatus'][index_list]=y_pred

# %%
df_mar.shape
# Out:
# (50679, 34)

# %%
dict_2={1:'Yes',0:'No' }

# %%
df_mar['MaritalStatus']=df_mar['MaritalStatus'].map(dict_2)

# %%
df_mar['MaritalStatus'].value_counts()
# Out:
# No     25388
# Yes    25291
# Name: MaritalStatus, dtype: int64

# %%
df1['New_maritalstatus']=df_mar['MaritalStatus']

# %%
sns.countplot(x = df1['New_maritalstatus'],hue=df1['Churn'])
# Out:
# <AxesSubplot: xlabel='New_maritalstatus', ylabel='count'>

# %%
# we do chi2 test of independence to check dependency on target variable

# %%
table = pd.crosstab(df1['Churn'], df1['New_maritalstatus'])
observed_values=table.values

# %%
test_stat, p, dof, expected_value = chi2_contingency(observed = observed_values, correction = False)

print("Test statistic:", test_stat)
print("p-value:", p)
print("Degrees of freedom:", dof)
print("Expected values:", expected_value)
# Out:
# Test statistic: 1.503467327320669
# p-value: 0.22013862680151292
# Degrees of freedom: 1
# Expected values: [[18122.62057262 18053.37942738]
#  [ 7265.37942738  7237.62057262]]

# %% [markdown]
# ### performing two_sample proportion test

# %%
table = pd.crosstab(df1['Churn'], df1['New_maritalstatus'])
table
# Out:
# New_maritalstatus     No    Yes
# Churn
# No                 18185  17991
# Yes                 7203   7300

# %% [markdown]
# * Ho: Prop(marrried_churners) = Prop (unmarried_churners)
# * Ha: Not equal

# %%
from statsmodels.stats.proportion import proportions_ztest
proportions_ztest([7203,7300],[25388,25291])
# Out:
# (-1.2261595847689, 0.22013862680152074)

# %% [markdown]
# * here p_value is > 0.05,hence we accept Ho ,proprtions are same.
# * since model preffered  is non linear we are proceeding with this column.

# %%
df1=df1.drop('MaritalStatus',axis=1)

# %%
df1.head()
# Out:
#   Churn  MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0   Yes       24.000000      219.000000             22.000000
# 1   Yes       16.990000       10.000000             17.000000
# 2    No       38.000000        8.000000             38.000000
# 3    No       82.280000     1312.000000             75.000000
# 4   Yes       17.140000        0.000000             17.000000
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0               0.250000        0.000000      0.000000        -157.000000
# 1               0.000000        0.000000      0.000000          -4.000000
# 2               0.000000        0.000000      0.000000          -2.000000
# 3               1.240000        0.000000      0.000000         157.000000
# 4               0.000000        0.000000      0.000000           0.000000
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0          -19.000000      0.700000      0.700000         6.300000
# 1            0.000000      0.300000      0.000000         2.700000
# 2            0.000000      0.000000      0.000000         0.000000
# 3            8.100000     52.000000      7.700000        76.000000
# 4           -0.200000      0.000000      0.000000         0.000000
#
#    CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0           0.000000       0.000000      97.200000       0.000000
# 1           0.000000       0.000000       0.000000       0.000000
# 2           0.000000       0.000000       0.400000       0.300000
# 3           4.300000       1.300000     200.300000     370.300000
# 4           0.000000       0.000000       0.000000       0.000000
#
#    InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0      0.000000       58.000000          24.000000             1.300000
# 1      0.000000        5.000000           1.000000             0.300000
# 2      0.000000        1.300000           3.700000             0.000000
# 3    147.000000      555.700000         303.700000            59.700000
# 4      0.000000        0.000000           0.000000             0.000000
#
#    CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0             0.000000          0.300000               61           2
# 1             0.000000          0.000000               58           1
# 2             0.000000          0.000000               60           1
# 3             0.000000         22.700000               59           2
# 4             0.000000          0.000000               53           2
#
#    ActiveSubs  Handsets  HandsetModels  CurrentEquipmentDays ChildrenInHH  \
# 0           1  2.000000       2.000000            361.000000           No
# 1           1  2.000000       1.000000           1504.000000          Yes
# 2           1  1.000000       1.000000           1812.000000          Yes
# 3           2  9.000000       4.000000            458.000000           No
# 4           2  4.000000       3.000000            852.000000           No
#
#   HandsetRefurbished HandsetWebCapable TruckOwner RVOwner Homeownership  \
# 0                 No               Yes         No      No         Known
# 1                 No                No         No      No         Known
# 2                 No                No         No      No       Unknown
# 3                 No               Yes         No      No         Known
# 4                 No                No         No      No         Known
#
#   BuysViaMailOrder RespondsToMailOffers OptOutMailings NonUSTravel  \
# 0              Yes                  Yes             No          No
# 1              Yes                  Yes             No          No
# 2               No                   No             No          No
# 3              Yes                  Yes             No          No
# 4              Yes                  Yes             No          No
#
#   OwnsComputer HasCreditCard  RetentionCalls  RetentionOffersAccepted  \
# 0          Yes           Yes               1                        0
# 1          Yes           Yes               0                        0
# 2           No           Yes               0                        0
# 3           No           Yes               0                        0
# 4          Yes           Yes               0                        0
#
#   NewCellphoneUser  ReferralsMadeBySubscriber  IncomeGroup OwnsMotorcycle  \
# 0               No                          0            4             No
# 1              Yes                          0            5             No
# 2              Yes                          0            6             No
# 3              Yes                          0            6             No
# 4               No                          0            9             No
#
#    AdjustmentsToCreditRating MadeCallToRetentionTeam CreditRating PrizmCode  \
# 0                          0                     Yes         High  Suburban
# 1                          0                      No       Medium  Suburban
# 2                          0                      No       Medium      Town
# 3                          0                      No       Medium     Other
# 4                          1                      No         High     Other
#
#      Occupation       Age New_maritalstatus
# 0  Professional 62.000000                No
# 1  Professional 41.000000               Yes
# 2        Crafts 26.000000               Yes
# 3         Other 30.000000                No
# 4  Professional 50.000000               Yes

# %%
# by the test we come to know that two variables are independent.

# %% [markdown]
# ## Outliers analysis

# %%
plt.figure(figsize=(20,30),dpi=100)
n=1
for i in df1.describe().columns:
    plt.subplot(18,2,n)
    n+=1
    sns.boxplot(df1[i],color='green')
    plt.title(f'{i.title()}',weight='bold')
    plt.tight_layout()

# %% [markdown]
# **Inference:** By Visualizing above Boxplot we can see that all the Features have potential outliers and some of the  features have certain extreme values.
#
# **Reason for outliers exist in the data:**
# 1. Variability in the Data
# 2. An experimental measurment error
#
# **Impact of outliers on Dataset:**
# 1. it causes various problem during statstical analysis
# 2. It effects the mean and standard deviation

# %% [markdown]
# ### Skewness Before Transformation

# %%
#checking and visualizing skewness of each feature by using dist plot
#checking skewness and normallity of data by visualizing graphs
plt.figure(figsize=(30,50),dpi=100)
n=1
for i in df1.describe().columns:
    plt.subplot(18,2,n)
    n+=1
    if df1[i].skew() < 0 :
        sns.histplot(df1[i] ,color='red',kde=True)
        plt.xlabel(f"{i}\nSkewness: {round(df1[i].skew(),4)}\nKurtois: {round(df1[i].kurt(),4)}",fontsize=15)
    else:
        sns.histplot(df1[i],color='teal',kde=True)
        plt.xlabel(f"{i}\nSkewness: {round(df1[i].skew(),4)}\nKurtois: {round(df1[i].kurt(),4)}",fontsize=15)
plt.tight_layout()

# %% [markdown]
# # Descriptive Statistics

# %% [markdown]
# ## univariate analysis

# %%
df1['Churn'].value_counts()
# Out:
# No     36176
# Yes    14503
# Name: Churn, dtype: int64

# %%
sns.catplot(x="Churn", kind="count", palette="ch:.25", data=df1)

# %% [markdown]
# ## univariate analysis on categorical column

# %%
# List only the Categorical columns
df_cat = df1.select_dtypes(include=['object']).columns
print(df_cat)
# Out:
# Index(['Churn', 'ChildrenInHH', 'HandsetRefurbished', 'HandsetWebCapable',
#        'TruckOwner', 'RVOwner', 'Homeownership', 'BuysViaMailOrder',
#        'RespondsToMailOffers', 'OptOutMailings', 'NonUSTravel', 'OwnsComputer',
#        'HasCreditCard', 'NewCellphoneUser', 'OwnsMotorcycle',
#        'MadeCallToRetentionTeam', 'CreditRating', 'PrizmCode', 'Occupation',
#        'New_maritalstatus'],
#       dtype='object')

# %%
def annot_percent(axes):
    for p in plot.patches:
        total = sum(p.get_height() for p in plot.patches)/100
        percent = round((p.get_height()/total),2)
        x = p.get_x() + p.get_width()/2
        y = p.get_height()
        plot.annotate(f'{percent}%', (x, y), ha='center', va='bottom')

# %%
#plotting countplot for some categorical variable

plt.figure(figsize=(15,25),dpi=100)
n=1
for i in df_cat:
    plot=plt.subplot(12,2,n)
    n+=1
    sns.countplot(df1[i] ,palette=sns.color_palette("hls", 8))
    plt.title(f'{i.title()}',weight='bold')
    plt.tight_layout()
    annot_percent(plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yc/db3vj0wd0xq2bm_6_93q6vl00000gn/T/ipykernel_13491/3065347265.py in <module>
#       6     plot=plt.subplot(12,2,n)
#       7     n+=1
# ----> 8     sns.countplot(df1[i] ,palette=sns.color_palette("hls", 8))
#       9     plt.title(f'{i.title()}',weight='bold')
#      10     plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940         raise ValueError("Cannot pass values for both `x` and `y`")
#    2941
# -> 2942     plotter = _CountPlotter(
#    2943         x, y, hue, data, order, hue_order,
#    2944         estimator, errorbar, n_boot, units, seed,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     514
#     515                 # Convert to a list of arrays, the common representation
# --> 516                 plot_data = [np.asarray(d, float) for d in plot_data]
#     517
#     518                 # The group names will just be numeric indices
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in <listcomp>(.0)
#     514
#     515                 # Convert to a list of arrays, the common representation
# --> 516                 plot_data = [np.asarray(d, float) for d in plot_data]
#     517
#     518                 # The group names will just be numeric indices
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
#     874     # ----------------------------------------------------------------------
#
# ValueError: could not convert string to float: 'Yes'

# %% [markdown]
# #### Obeservations
#
# 1) Churn Over 28 percent of people in the data have churned.
#
# 2) Handseter capable More than 90 percent of the people in the data have internet support on their phone.
#
# 3) More than 65 percent of them don't have a credit card
#
# 4) Less than 2 percent of them own a motorcycle
#
# 5) In occupations category over 73% are 'other'.
#
# 6) new_marital status has almost equal count.

# %% [markdown]
# ## Univariate Analysis on Numerical Columns

# %%
df_num=df1.select_dtypes(include=np.number)

# %%
# Kde Plot for Numerical features

plt.figure(figsize=(15,25),dpi=100)
n=1
for i in df_num:
    plot=plt.subplot(18,2,n)
    n+=1
    plt.title(i)
    sns.kdeplot(data=df1[i])
    plt.tight_layout()
    annot_percent(plot)

# %% [markdown]
# ## Bivariate Analysis

# %% [markdown]
# ### Bivariate Analysis on Categorical - Categorical

# %%
plt.figure(figsize=(15,30),dpi=100)
n=1
for i in df_cat:
    plot=plt.subplot(12,2,n)
    n+=1
    sns.countplot(df1[i],hue= df1['Churn'] ,palette=sns.color_palette("hls", 8))
    plt.title(f'{i.title()}',weight='bold')
    plt.tight_layout()
    annot_percent(plot)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/yc/db3vj0wd0xq2bm_6_93q6vl00000gn/T/ipykernel_13491/331415140.py in <module>
#       4     plot=plt.subplot(12,2,n)
#       5     n+=1
# ----> 6     sns.countplot(df1[i],hue= df1['Churn'] ,palette=sns.color_palette("hls", 8))
#       7     plt.title(f'{i.title()}',weight='bold')
#       8     plt.tight_layout()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in countplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, width, dodge, ax, **kwargs)
#    2940         raise ValueError("Cannot pass values for both `x` and `y`")
#    2941
# -> 2942     plotter = _CountPlotter(
#    2943         x, y, hue, data, order, hue_order,
#    2944         estimator, errorbar, n_boot, units, seed,
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in __init__(self, x, y, hue, data, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge)
#    1528                  errcolor, errwidth, capsize, dodge):
#    1529         """Initialize the plotter."""
# -> 1530         self.establish_variables(x, y, hue, data, orient,
#    1531                                  order, hue_order, units)
#    1532         self.establish_colors(color, palette, saturation)
#
# ~/opt/anaconda3/lib/python3.9/site-packages/seaborn/categorical.py in establish_variables(self, x, y, hue, data, orient, order, hue_order, units)
#     435             if hue is not None:
#     436                 error = "Cannot use `hue` without `x` and `y`"
# --> 437                 raise ValueError(error)
#     438
#     439             # No hue grouping with wide inputs
#
# ValueError: Cannot use `hue` without `x` and `y`

# %% [markdown]
# ###  observation:
#
# 1. In Handset web capability over 25% of people who have churned has more than 90% of Internet capability on their phone.
#
#
# 2. Less than 6% of people who own New phone have churned
#
#
# 3. Data show that people who have Credit Cards are more likely to Churn
#
#
# 4. Marital Status of people churning is independent
#
#
# 5. People who have responded mail offer are less likely to churn

# %% [markdown]
# ## Multivariate Analysis

# %%
plt.rcParams['figure.figsize']=[20,8]
sns.scatterplot(x="MonthlyRevenue", y="MonthlyMinutes",hue='Churn', data=df1)

# %% [markdown]
# ### Observation
#
# According plot as number of Monthly Minutes increases ,Monthly Revenue is increasing, and churn points are completely overlapping.

# %% [markdown]
# # Statistics

# %% [markdown]
# ## **Chi-Square Test for Independence**

# %% [markdown]
# This test is used to test whether the categorical variables are independent or not.
#
# <p style='text-indent:20em'> <strong> $H_{0}$: The variables are independent</strong></p>
# <p style='text-indent:20em'> <strong> $H_{1}$: The variables are not independent (i.e. variables are dependent)</strong></p>

# %% [markdown]
# Here we can check if the catagorical features are dependent on our target.<br>
# We are assuming the level of confidence as 95%

# %%
# taking only the catagorical variables
df_categorical=df1.select_dtypes(include=object)
df_categorical.head()
# Out:
#   Churn ChildrenInHH HandsetRefurbished HandsetWebCapable TruckOwner RVOwner  \
# 0   Yes           No                 No               Yes         No      No
# 1   Yes          Yes                 No                No         No      No
# 2    No          Yes                 No                No         No      No
# 3    No           No                 No               Yes         No      No
# 4   Yes           No                 No                No         No      No
#
#   Homeownership BuysViaMailOrder RespondsToMailOffers OptOutMailings  \
# 0         Known              Yes                  Yes             No
# 1         Known              Yes                  Yes             No
# 2       Unknown               No                   No             No
# 3         Known              Yes                  Yes             No
# 4         Known              Yes                  Yes             No
#
#   NonUSTravel OwnsComputer HasCreditCard NewCellphoneUser OwnsMotorcycle  \
# 0          No          Yes           Yes               No             No
# 1          No          Yes           Yes              Yes             No
# 2          No           No           Yes              Yes             No
# 3          No           No           Yes              Yes             No
# 4          No          Yes           Yes               No             No
#
#   MadeCallToRetentionTeam CreditRating PrizmCode    Occupation  \
# 0                     Yes         High  Suburban  Professional
# 1                      No       Medium  Suburban  Professional
# 2                      No       Medium      Town        Crafts
# 3                      No       Medium     Other         Other
# 4                      No         High     Other  Professional
#
#   New_maritalstatus
# 0                No
# 1               Yes
# 2               Yes
# 3                No
# 4               Yes

# %%
# taking only the features from catagories
df_categorical_features=df_categorical.drop('Churn',axis=1)
df_target=df_categorical['Churn']

# %%
for i in df_categorical_features.columns:
    
    print('for: ',i)
    
    print('The null and alternative hypothesis is:')
    print(' ')
    print('H0: The variables {} and churn are independent'.format(i))
    print('H1: The variables {} and churn are not independent'.format(i))
    print('')
    
    table=pd.crosstab(df_categorical_features[i],df_target)
    observed_value=table.values
    
    # use the 'chi2_contingency()' to check the independence of variables
    # the function returns the test statistic value, corresponding p-value, degrees of freedom of the test and expected values
    # pass the observed values to the parameter, 'observed'
    # 'correction = False' will not apply the Yates' correction
    test_stat, p, dof, expected_value = chi2_contingency(observed = observed_value, correction = False)

    print("Test statistic:", test_stat)
    print("p-value:", p)
    print("Degrees of freedom:", dof) 
    print("Expected values:", '\n',expected_value)
    
    if p > 0.05:
        print('The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables {} and Churn are independent.'.format(i))
    else:
        print('The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables {} and Churn are dependent.'.format(i))
# Out:
# for:  ChildrenInHH
# The null and alternative hypothesis is:
#
# H0: The variables ChildrenInHH and churn are independent
# H1: The variables ChildrenInHH and churn are not independent
#
# Test statistic: 4.698156215718356
# p-value: 0.030194993311185508
# Degrees of freedom: 1
# Expected values:
#  [[27409.49995067 10988.50004933]
#  [ 8766.50004933  3514.49995067]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables ChildrenInHH and Churn are dependent.
# for:  HandsetRefurbished
# The null and alternative hypothesis is:
#
# H0: The variables HandsetRefurbished and churn are independent
# H1: The variables HandsetRefurbished and churn are not independent
#
# Test statistic: 47.97838353216636
# p-value: 4.309441911549537e-12
# Degrees of freedom: 1
# Expected values:
#  [[31163.51214507 12493.48785493]
#  [ 5012.48785493  2009.51214507]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables HandsetRefurbished and Churn are dependent.
# for:  HandsetWebCapable
# The null and alternative hypothesis is:
#
# H0: The variables HandsetWebCapable and churn are independent
# H1: The variables HandsetWebCapable and churn are not independent
#
# Test statistic: 196.2392348658804
# p-value: 1.3821435319040625e-44
# Degrees of freedom: 1
# Expected values:
#  [[ 3509.88362043  1407.11637957]
#  [32666.11637957 13095.88362043]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables HandsetWebCapable and Churn are dependent.
# for:  TruckOwner
# The null and alternative hypothesis is:
#
# H0: The variables TruckOwner and churn are independent
# H1: The variables TruckOwner and churn are not independent
#
# Test statistic: 0.9693925629899549
# p-value: 0.3248317186560239
# Degrees of freedom: 1
# Expected values:
#  [[29406.07194301 11788.92805699]
#  [ 6769.92805699  2714.07194301]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables TruckOwner and Churn are independent.
# for:  RVOwner
# The null and alternative hypothesis is:
#
# H0: The variables RVOwner and churn are independent
# H1: The variables RVOwner and churn are not independent
#
# Test statistic: 0.4531319927999258
# p-value: 0.5008513613156514
# Degrees of freedom: 1
# Expected values:
#  [[33220.75936779 13318.24063221]
#  [ 2955.24063221  1184.75936779]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables RVOwner and Churn are independent.
# for:  Homeownership
# The null and alternative hypothesis is:
#
# H0: The variables Homeownership and churn are independent
# H1: The variables Homeownership and churn are not independent
#
# Test statistic: 7.9045395191243335
# p-value: 0.004931089258936731
# Degrees of freedom: 1
# Expected values:
#  [[24088.06645751  9656.93354249]
#  [12087.93354249  4846.06645751]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables Homeownership and Churn are dependent.
# for:  BuysViaMailOrder
# The null and alternative hypothesis is:
#
# H0: The variables BuysViaMailOrder and churn are independent
# H1: The variables BuysViaMailOrder and churn are not independent
#
# Test statistic: 22.739748845809853
# p-value: 1.8549099805829533e-06
# Degrees of freedom: 1
# Expected values:
#  [[23090.13737445  9256.86262555]
#  [13085.86262555  5246.13737445]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables BuysViaMailOrder and Churn are dependent.
# for:  RespondsToMailOffers
# The null and alternative hypothesis is:
#
# H0: The variables RespondsToMailOffers and churn are independent
# H1: The variables RespondsToMailOffers and churn are not independent
#
# Test statistic: 25.31135961315004
# p-value: 4.878273257499392e-07
# Degrees of freedom: 1
# Expected values:
#  [[22544.06030111  9037.93969889]
#  [13631.93969889  5465.06030111]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables RespondsToMailOffers and Churn are dependent.
# for:  OptOutMailings
# The null and alternative hypothesis is:
#
# H0: The variables OptOutMailings and churn are independent
# H1: The variables OptOutMailings and churn are not independent
#
# Test statistic: 0.04210554167857867
# p-value: 0.8374187217642836
# Degrees of freedom: 1
# Expected values:
#  [[35643.48562521 14289.51437479]
#  [  532.51437479   213.48562521]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables OptOutMailings and Churn are independent.
# for:  NonUSTravel
# The null and alternative hypothesis is:
#
# H0: The variables NonUSTravel and churn are independent
# H1: The variables NonUSTravel and churn are not independent
#
# Test statistic: 0.3357727844456926
# p-value: 0.5622794735918317
# Degrees of freedom: 1
# Expected values:
#  [[34136.59843328 13685.40156672]
#  [ 2039.40156672   817.59843328]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables NonUSTravel and Churn are independent.
# for:  OwnsComputer
# The null and alternative hypothesis is:
#
# H0: The variables OwnsComputer and churn are independent
# H1: The variables OwnsComputer and churn are not independent
#
# Test statistic: 0.0572332950823896
# p-value: 0.8109235104922659
# Degrees of freedom: 1
# Expected values:
#  [[29472.4577833 11815.5422167]
#  [ 6703.5422167  2687.4577833]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables OwnsComputer and Churn are independent.
# for:  HasCreditCard
# The null and alternative hypothesis is:
#
# H0: The variables HasCreditCard and churn are independent
# H1: The variables HasCreditCard and churn are not independent
#
# Test statistic: 3.253401465520138
# p-value: 0.07127540271874062
# Degrees of freedom: 1
# Expected values:
#  [[11718.88537659  4698.11462341]
#  [24457.11462341  9804.88537659]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables HasCreditCard and Churn are independent.
# for:  NewCellphoneUser
# The null and alternative hypothesis is:
#
# H0: The variables NewCellphoneUser and churn are independent
# H1: The variables NewCellphoneUser and churn are not independent
#
# Test statistic: 2.162717651275268
# p-value: 0.14139442113453202
# Degrees of freedom: 1
# Expected values:
#  [[29189.06876616 11701.93123384]
#  [ 6986.93123384  2801.06876616]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables NewCellphoneUser and Churn are independent.
# for:  OwnsMotorcycle
# The null and alternative hypothesis is:
#
# H0: The variables OwnsMotorcycle and churn are independent
# H1: The variables OwnsMotorcycle and churn are not independent
#
# Test statistic: 2.8910885906197445
# p-value: 0.08907072348768776
# Degrees of freedom: 1
# Expected values:
#  [[35694.16728823 14309.83271177]
#  [  481.83271177   193.16728823]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables OwnsMotorcycle and Churn are independent.
# for:  MadeCallToRetentionTeam
# The null and alternative hypothesis is:
#
# H0: The variables MadeCallToRetentionTeam and churn are independent
# H1: The variables MadeCallToRetentionTeam and churn are not independent
#
# Test statistic: 182.83394898266914
# p-value: 1.1659511482336312e-41
# Degrees of freedom: 1
# Expected values:
#  [[34998.90053079 14031.09946921]
#  [ 1177.09946921   471.90053079]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables MadeCallToRetentionTeam and Churn are dependent.
# for:  CreditRating
# The null and alternative hypothesis is:
#
# H0: The variables CreditRating and churn are independent
# H1: The variables CreditRating and churn are not independent
#
# Test statistic: 144.79211724306955
# p-value: 3.6206890545132067e-32
# Degrees of freedom: 2
# Expected values:
#  [[19527.43061229  7828.56938771]
#  [ 6899.84443261  2766.15556739]
#  [ 9748.72495511  3908.27504489]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables CreditRating and Churn are dependent.
# for:  PrizmCode
# The null and alternative hypothesis is:
#
# H0: The variables PrizmCode and churn are independent
# H1: The variables PrizmCode and churn are not independent
#
# Test statistic: 18.839355979101004
# p-value: 0.00029512488374545005
# Degrees of freedom: 3
# Expected values:
#  [[17457.33451726  6998.66548274]
#  [ 1718.89358511   689.10641489]
#  [11603.24552576  4651.75447424]
#  [ 5396.52637187  2163.47362813]]
# The above output shows that the chi-square the p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables PrizmCode and Churn are dependent.
# for:  Occupation
# The null and alternative hypothesis is:
#
# H0: The variables Occupation and churn are independent
# H1: The variables Occupation and churn are not independent
#
# Test statistic: 8.989873760871856
# p-value: 0.25338388762713937
# Degrees of freedom: 7
# Expected values:
#  [[  698.83588863   280.16411137]
#  [ 1076.44996942   431.55003058]
#  [  112.07071963    44.92928037]
#  [26674.25892381 10693.74107619]
#  [ 6203.15002269  2486.84997731]
#  [  518.95167624   208.04832376]
#  [  622.45648099   249.54351901]
#  [  269.82631859   108.17368141]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables Occupation and Churn are independent.
# for:  New_maritalstatus
# The null and alternative hypothesis is:
#
# H0: The variables New_maritalstatus and churn are independent
# H1: The variables New_maritalstatus and churn are not independent
#
# Test statistic: 1.503467327320669
# p-value: 0.22013862680151292
# Degrees of freedom: 1
# Expected values:
#  [[18122.62057262  7265.37942738]
#  [18053.37942738  7237.62057262]]
# The above output shows that the chi-square the p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables New_maritalstatus and Churn are independent.

# %%
print('The dependent categorical variable found after Chi-Square Test for Independence are:')
print('')
for i in df_categorical_features.columns:
    table=pd.crosstab(df_categorical_features[i],df_target)
    observed_value=table.values
    test_stat, p, dof, expected_value = chi2_contingency(observed = observed_value, correction = False)
    if p < 0.05:
        print(i)
# Out:
# The dependent categorical variable found after Chi-Square Test for Independence are:
#
# ChildrenInHH
# HandsetRefurbished
# HandsetWebCapable
# Homeownership
# BuysViaMailOrder
# RespondsToMailOffers
# MadeCallToRetentionTeam
# CreditRating
# PrizmCode

# %%
print('The independent categorical variable found after Chi-Square Test for Independence are:')
print('')
for i in df_categorical_features.columns:
    table=pd.crosstab(df_categorical_features[i],df_target)
    observed_value=table.values
    test_stat, p, dof, expected_value = chi2_contingency(observed = observed_value, correction = False)
    if p > 0.05:
        print(i)
# Out:
# The independent categorical variable found after Chi-Square Test for Independence are:
#
# TruckOwner
# RVOwner
# OptOutMailings
# NonUSTravel
# OwnsComputer
# HasCreditCard
# NewCellphoneUser
# OwnsMotorcycle
# Occupation
# New_maritalstatus

# %% [markdown]
# ## Checking significance for numerical features

# %%
df_num=df1.select_dtypes(include=np.number)
df_target=df_categorical['Churn']
df_num.head(2)
# Out:
#    MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0       24.000000      219.000000             22.000000
# 1       16.990000       10.000000             17.000000
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0               0.250000        0.000000      0.000000        -157.000000
# 1               0.000000        0.000000      0.000000          -4.000000
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0          -19.000000      0.700000      0.700000         6.300000
# 1            0.000000      0.300000      0.000000         2.700000
#
#    CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0           0.000000       0.000000      97.200000       0.000000
# 1           0.000000       0.000000       0.000000       0.000000
#
#    InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0      0.000000       58.000000          24.000000             1.300000
# 1      0.000000        5.000000           1.000000             0.300000
#
#    CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0             0.000000          0.300000               61           2
# 1             0.000000          0.000000               58           1
#
#    ActiveSubs  Handsets  HandsetModels  CurrentEquipmentDays  RetentionCalls  \
# 0           1  2.000000       2.000000            361.000000               1
# 1           1  2.000000       1.000000           1504.000000               0
#
#    RetentionOffersAccepted  ReferralsMadeBySubscriber  IncomeGroup  \
# 0                        0                          0            4
# 1                        0                          0            5
#
#    AdjustmentsToCreditRating       Age
# 0                          0 62.000000
# 1                          0 41.000000

# %% [markdown]
# ### Jarque-Bera test

# %% [markdown]
# The null and alternative hypothesis for jarque_bera is given as:
# <p style='text-indent:20em'> <strong> $H_{0}$: The data is normally distributed. </strong></p>
# <p style='text-indent:20em'> <strong> $H_{1}$: The data is not normally distributed. </strong></p>
#
# Assuming the level of confidence as 95%

# %%
# importing jarque_bera function from the scipy.stats library
from scipy.stats import jarque_bera

# %%
def get_jarque_bera(Churn_Yes_set,Churn_No_set):
    stat_co,p_co=jarque_bera(Churn_Yes_set)
    stat_fp,p_fp=jarque_bera(Churn_No_set)
    if p_co > 0.05 and p_fp > 0.05:
        print('Since the pvalue of both the Churners and non_churners are greater then 0.05, we donot have enough evidence to reject the null hypothesis for both')
        print('Both sets are normaly distributed')
    elif p_co < 0.05 and p_fp < 0.05: 
        print('Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis')
        print('Both sets are not normaly distributed')
    elif p_co < 0.05 or p_fp < 0.05: 
        print('Since the pvalue of either the Churners and non_churners are lesser then 0.05, we reject the null hypothesis of the variable with p_value < 0.05 ')
        print('Either one of sets is not normaly distributed')

# %% [markdown]
# #### we will saperate each numerical column into two sets according to the target variable which are in this case Yes and No

# %%
for i in df_num.columns:
    print('Checking the normality of the two separated sets of {} column according to target'.format(i))
    print()
    Churn_Yes_set=df1[df1['Churn']=='Yes'][i]
    Churn_No_set=df1[df1['Churn']=='No'][i]
    print(get_jarque_bera(Churn_Yes_set,Churn_No_set))
# Out:
# Checking the normality of the two separated sets of MonthlyRevenue column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of MonthlyMinutes column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of TotalRecurringCharge column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of DirectorAssistedCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of OverageMinutes column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of RoamingCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of PercChangeMinutes column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of PercChangeRevenues column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of DroppedCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of BlockedCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of UnansweredCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of CustomerCareCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of ThreewayCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of ReceivedCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of OutboundCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of InboundCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of PeakCallsInOut column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of OffPeakCallsInOut column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of DroppedBlockedCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of CallForwardingCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of CallWaitingCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of MonthsInService column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of UniqueSubs column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of ActiveSubs column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of Handsets column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of HandsetModels column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of CurrentEquipmentDays column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of RetentionCalls column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of RetentionOffersAccepted column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of ReferralsMadeBySubscriber column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of IncomeGroup column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of AdjustmentsToCreditRating column according to target
#
# Since the pvalue of both the Churners and non_churnersare lesser then 0.05, we reject the null hypothesis
# Both sets are not normaly distributed
# None
# Checking the normality of the two separated sets of Age column according to target
#
# None

# %% [markdown]
# Inference:
# 1. we can see that none of the sets of the numerical features separated by the target variables are normally distributed,therefore we can opt for `kruskal wallis test` to check its dependence on the target variable

# %% [markdown]
# ### Kruskal wallis test

# %% [markdown]
# The null and alternative hypothesis for `kruskal wallis test` is given as:
# <p style='text-indent:20em'> <strong> $H_{0}$: The data samples are with equal median (independent). </strong></p>
# <p style='text-indent:20em'> <strong> $H_{1}$: The data samples do not have equal median(i.e. variables are dependent). </strong></p>
#
# Assuming the level of confidence as 95%

# %%
# importing the kruskal function from the scipy.stats library 
from scipy.stats import kruskal

# %%
x=df1['Churn'].value_counts().index[0]
y=df1['Churn'].value_counts().index[1]

# %%
for i in df_num.columns:
    
    print('for: ',i)
    
  
    Churn_Yes_set=df1[df1['Churn']=='Yes'][i]
    Churn_No_set=df1[df1['Churn']=='No'][i]
    
    # use the 'kruskal()' to check the independence of variables
    # the function returns the test statistic value, corresponding p-value
    # pass the separated values of each numerical columns according to the target variable which
    test_stat, p = kruskal(Churn_Yes_set,Churn_No_set)

    print("Test statistic:", test_stat)
    print("p-value:", p)
   
    
    if p > 0.05:
        print('The above output shows that the H-test p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables {} is not contributing to target Churn'.format(i))
    else:
        print('The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables {} is contributing to target Churn.'.format(i))
# Out:
# for:  MonthlyRevenue
# Test statistic: 26.53870020240826
# p-value: 2.5831119673718165e-07
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables MonthlyRevenue is contributing to target Churn.
# for:  MonthlyMinutes
# Test statistic: 194.2062602972561
# p-value: 3.8392525154374923e-44
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables MonthlyMinutes is contributing to target Churn.
# for:  TotalRecurringCharge
# Test statistic: 210.5035724811127
# p-value: 1.0665990104457013e-47
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables TotalRecurringCharge is contributing to target Churn.
# for:  DirectorAssistedCalls
# Test statistic: 29.409520626871327
# p-value: 5.8589103656863455e-08
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables DirectorAssistedCalls is contributing to target Churn.
# for:  OverageMinutes
# Test statistic: 19.73939116474458
# p-value: 8.875299441853716e-06
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables OverageMinutes is contributing to target Churn.
# for:  RoamingCalls
# Test statistic: 0.009394663606370764
# p-value: 0.9227851031139467
# The above output shows that the H-test p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables RoamingCalls is not contributing to target Churn
# for:  PercChangeMinutes
# Test statistic: 121.2470877835375
# p-value: 3.3738279893000977e-28
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables PercChangeMinutes is contributing to target Churn.
# for:  PercChangeRevenues
# Test statistic: 1.0387941935314535
# p-value: 0.3081020764861519
# The above output shows that the H-test p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables PercChangeRevenues is not contributing to target Churn
# for:  DroppedCalls
# Test statistic: 28.980830728438782
# p-value: 7.309808162489954e-08
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables DroppedCalls is contributing to target Churn.
# for:  BlockedCalls
# Test statistic: 11.62619681353626
# p-value: 0.0006502938407387024
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables BlockedCalls is contributing to target Churn.
# for:  UnansweredCalls
# Test statistic: 97.3888009191752
# p-value: 5.69673227067598e-23
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables UnansweredCalls is contributing to target Churn.
# for:  CustomerCareCalls
# Test statistic: 135.37126521451518
# p-value: 2.7386030920008797e-31
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables CustomerCareCalls is contributing to target Churn.
# for:  ThreewayCalls
# Test statistic: 45.97540002945172
# p-value: 1.1974724268339328e-11
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables ThreewayCalls is contributing to target Churn.
# for:  ReceivedCalls
# Test statistic: 107.3699285235286
# p-value: 3.6936884829461924e-25
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables ReceivedCalls is contributing to target Churn.
# for:  OutboundCalls
# Test statistic: 96.98408076190162
# p-value: 6.988697438550353e-23
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables OutboundCalls is contributing to target Churn.
# for:  InboundCalls
# Test statistic: 147.71576236592404
# p-value: 5.473492190483929e-34
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables InboundCalls is contributing to target Churn.
# for:  PeakCallsInOut
# Test statistic: 110.05970564272278
# p-value: 9.508331932227858e-26
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables PeakCallsInOut is contributing to target Churn.
# for:  OffPeakCallsInOut
# Test statistic: 145.7058117244659
# p-value: 1.5054123741745793e-33
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables OffPeakCallsInOut is contributing to target Churn.
# for:  DroppedBlockedCalls
# Test statistic: 33.22753762822632
# p-value: 8.198129429544385e-09
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables DroppedBlockedCalls is contributing to target Churn.
# for:  CallForwardingCalls
# Test statistic: 1.0226680938895611
# p-value: 0.3118869647487916
# The above output shows that the H-test p-value is greater than 0.05, thus we fail to reject (i.e. accept) the null hypothesis and conclude that the variables CallForwardingCalls is not contributing to target Churn
# for:  CallWaitingCalls
# Test statistic: 66.71062622633778
# p-value: 3.1443554386703787e-16
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables CallWaitingCalls is contributing to target Churn.
# for:  MonthsInService
# Test statistic: 77.51518940675248
# p-value: 1.3170570561774175e-18
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables MonthsInService is contributing to target Churn.
# for:  UniqueSubs
# Test statistic: 95.89866144056775
# p-value: 1.2091711157650763e-22
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables UniqueSubs is contributing to target Churn.
# for:  ActiveSubs
# Test statistic: 21.812578453066553
# p-value: 3.0062283847546045e-06
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables ActiveSubs is contributing to target Churn.
# for:  Handsets
# Test statistic: 66.37793750250603
# p-value: 3.722453545449708e-16
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables Handsets is contributing to target Churn.
# for:  HandsetModels
# Test statistic: 88.87310634847817
# p-value: 4.209676778621065e-21
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables HandsetModels is contributing to target Churn.
# for:  CurrentEquipmentDays
# Test statistic: 676.7276538465007
# p-value: 3.4399393706687e-149
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables CurrentEquipmentDays is contributing to target Churn.
# for:  RetentionCalls
# Test statistic: 182.8465134225253
# p-value: 1.158609961043007e-41
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables RetentionCalls is contributing to target Churn.
# for:  RetentionOffersAccepted
# Test statistic: 62.759099988618864
# p-value: 2.3359977866485644e-15
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables RetentionOffersAccepted is contributing to target Churn.
# for:  ReferralsMadeBySubscriber
# Test statistic: 5.0333979196767435
# p-value: 0.02486307296659036
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables ReferralsMadeBySubscriber is contributing to target Churn.
# for:  IncomeGroup
# Test statistic: 4.954210911835101
# p-value: 0.026027200401497905
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables IncomeGroup is contributing to target Churn.
# for:  AdjustmentsToCreditRating
# Test statistic: 11.639429454176028
# p-value: 0.0006456840429229511
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables AdjustmentsToCreditRating is contributing to target Churn.
# for:  Age
# Test statistic: nan
# p-value: nan
# The above output shows that the H-test p-value is lesser than 0.05, thus we  reject  the null hypothesis and conclude that the variables Age is contributing to target Churn.

# %%
print('The dependent numerical variable found after H-test Test:')
print(' ') 
for i in df_num.columns:
    Churn_Yes_set=df1[df1['Churn']=='Yes'][i]
    Churn_No_set=df1[df1['Churn']=='No'][i]
    test_stat, p = kruskal(Churn_Yes_set,Churn_No_set)
    if p < 0.05:
        print(i)
# Out:
# The dependent numerical variable found after H-test Test:
#
# MonthlyRevenue
# MonthlyMinutes
# TotalRecurringCharge
# DirectorAssistedCalls
# OverageMinutes
# PercChangeMinutes
# DroppedCalls
# BlockedCalls
# UnansweredCalls
# CustomerCareCalls
# ThreewayCalls
# ReceivedCalls
# OutboundCalls
# InboundCalls
# PeakCallsInOut
# OffPeakCallsInOut
# DroppedBlockedCalls
# CallWaitingCalls
# MonthsInService
# UniqueSubs
# ActiveSubs
# Handsets
# HandsetModels
# CurrentEquipmentDays
# RetentionCalls
# RetentionOffersAccepted
# ReferralsMadeBySubscriber
# IncomeGroup
# AdjustmentsToCreditRating

# %%
print('The independent numerical variable found after H-test Test:')
print('')
for i in df_num.columns:
    Churn_Yes_set=df1[df1['Churn']=='Yes'][i]
    Churn_No_set=df1[df1['Churn']=='No'][i]
    test_stat, p = kruskal(Churn_Yes_set,Churn_No_set)
    if p > 0.05:
        print(i)
# Out:
# The independent numerical variable found after H-test Test:
#
# RoamingCalls
# PercChangeRevenues
# CallForwardingCalls

# %%
significant_variable=pd.DataFrame(columns=['Feature','Statistical Test','P-Value','Inference'])

# %%
for i in df_num.columns:
    Churn_Yes_set=df1[df1['Churn']=='Yes'][i]
    Churn_No_set=df1[df1['Churn']=='No'][i]
    test_stat, p = kruskal(Churn_Yes_set,Churn_No_set)
    
    if p < 0.05:
        seg_ser=pd.Series({'Feature': i,
                          'Statistical Test':'kruskal wallis test',
                          'P-Value':p,
                          'Inference':'Dependent numerical variable found after H-test Test'})
        significant_variable = significant_variable.append(seg_ser, ignore_index=True)
    else:
        seg_ser=pd.Series({'Feature': i,
                          'Statistical Test':'kruskal wallis test',
                          'P-Value':p,
                          'Inference':'Independent numerical variable found after H-test Test'})
        significant_variable = significant_variable.append(seg_ser, ignore_index=True)
        
significant_variable
# Out:
#                       Feature     Statistical Test  P-Value  \
# 0              MonthlyRevenue  kruskal wallis test 0.000000
# 1              MonthlyMinutes  kruskal wallis test 0.000000
# 2        TotalRecurringCharge  kruskal wallis test 0.000000
# 3       DirectorAssistedCalls  kruskal wallis test 0.000000
# 4              OverageMinutes  kruskal wallis test 0.000009
# 5                RoamingCalls  kruskal wallis test 0.922785
# 6           PercChangeMinutes  kruskal wallis test 0.000000
# 7          PercChangeRevenues  kruskal wallis test 0.308102
# 8                DroppedCalls  kruskal wallis test 0.000000
# 9                BlockedCalls  kruskal wallis test 0.000650
# 10            UnansweredCalls  kruskal wallis test 0.000000
# 11          CustomerCareCalls  kruskal wallis test 0.000000
# 12              ThreewayCalls  kruskal wallis test 0.000000
# 13              ReceivedCalls  kruskal wallis test 0.000000
# 14              OutboundCalls  kruskal wallis test 0.000000
# 15               InboundCalls  kruskal wallis test 0.000000
# 16             PeakCallsInOut  kruskal wallis test 0.000000
# 17          OffPeakCallsInOut  kruskal wallis test 0.000000
# 18        DroppedBlockedCalls  kruskal wallis test 0.000000
# 19        CallForwardingCalls  kruskal wallis test 0.311887
# 20           CallWaitingCalls  kruskal wallis test 0.000000
# 21            MonthsInService  kruskal wallis test 0.000000
# 22                 UniqueSubs  kruskal wallis test 0.000000
# 23                 ActiveSubs  kruskal wallis test 0.000003
# 24                   Handsets  kruskal wallis test 0.000000
# 25              HandsetModels  kruskal wallis test 0.000000
# 26       CurrentEquipmentDays  kruskal wallis test 0.000000
# 27             RetentionCalls  kruskal wallis test 0.000000
# 28    RetentionOffersAccepted  kruskal wallis test 0.000000
# 29  ReferralsMadeBySubscriber  kruskal wallis test 0.024863
# 30                IncomeGroup  kruskal wallis test 0.026027
# 31  AdjustmentsToCreditRating  kruskal wallis test 0.000646
# 32                        Age  kruskal wallis test      NaN
#
#                                             Inference
# 0   Dependent numerical variable found after H-tes...
# 1   Dependent numerical variable found after H-tes...
# 2   Dependent numerical variable found after H-tes...
# 3   Dependent numerical variable found after H-tes...
# 4   Dependent numerical variable found after H-tes...
# 5   Independent numerical variable found after H-t...
# 6   Dependent numerical variable found after H-tes...
# 7   Independent numerical variable found after H-t...
# 8   Dependent numerical variable found after H-tes...
# 9   Dependent numerical variable found after H-tes...
# 10  Dependent numerical variable found after H-tes...
# 11  Dependent numerical variable found after H-tes...
# 12  Dependent numerical variable found after H-tes...
# 13  Dependent numerical variable found after H-tes...
# 14  Dependent numerical variable found after H-tes...
# 15  Dependent numerical variable found after H-tes...
# 16  Dependent numerical variable found after H-tes...
# 17  Dependent numerical variable found after H-tes...
# 18  Dependent numerical variable found after H-tes...
# 19  Independent numerical variable found after H-t...
# 20  Dependent numerical variable found after H-tes...
# 21  Dependent numerical variable found after H-tes...
# 22  Dependent numerical variable found after H-tes...
# 23  Dependent numerical variable found after H-tes...
# 24  Dependent numerical variable found after H-tes...
# 25  Dependent numerical variable found after H-tes...
# 26  Dependent numerical variable found after H-tes...
# 27  Dependent numerical variable found after H-tes...
# 28  Dependent numerical variable found after H-tes...
# 29  Dependent numerical variable found after H-tes...
# 30  Dependent numerical variable found after H-tes...
# 31  Dependent numerical variable found after H-tes...
# 32  Independent numerical variable found after H-t...

# %%
for i in df_categorical_features.columns:
    table=pd.crosstab(df_categorical_features[i],df_target)
    observed_value=table.values
    
    
    test_stat, p, dof, expected_value = chi2_contingency(observed = observed_value, correction = False)
    
    if p < 0.05:
        seg_ser=pd.Series({'Feature': i,
                          'Statistical Test':'Chi-Square Test for Independence',
                          'P-Value':p,
                          'Inference':'Dependent categorical variable found after Chi-Square Test for Independence'})
        significant_variable = significant_variable.append(seg_ser, ignore_index=True)
    else:
        seg_ser=pd.Series({'Feature': i,
                          'Statistical Test':'Chi-Square Test for Independence',
                          'P-Value':p,
                          'Inference':'Independent categorical variable found after Chi-Square Test for Independence'})
        significant_variable = significant_variable.append(seg_ser, ignore_index=True)
        
significant_variable
# Out:
#                     Feature                  Statistical Test  P-Value  \
# 0            MonthlyRevenue               kruskal wallis test 0.000000
# 1            MonthlyMinutes               kruskal wallis test 0.000000
# 2      TotalRecurringCharge               kruskal wallis test 0.000000
# 3     DirectorAssistedCalls               kruskal wallis test 0.000000
# 4            OverageMinutes               kruskal wallis test 0.000009
# ..                      ...                               ...      ...
# 47  MadeCallToRetentionTeam  Chi-Square Test for Independence 0.000000
# 48             CreditRating  Chi-Square Test for Independence 0.000000
# 49                PrizmCode  Chi-Square Test for Independence 0.000295
# 50               Occupation  Chi-Square Test for Independence 0.253384
# 51        New_maritalstatus  Chi-Square Test for Independence 0.220139
#
#                                             Inference
# 0   Dependent numerical variable found after H-tes...
# 1   Dependent numerical variable found after H-tes...
# 2   Dependent numerical variable found after H-tes...
# 3   Dependent numerical variable found after H-tes...
# 4   Dependent numerical variable found after H-tes...
# ..                                                ...
# 47  Dependent categorical variable found after Chi...
# 48  Dependent categorical variable found after Chi...
# 49  Dependent categorical variable found after Chi...
# 50  Independent categorical variable found after C...
# 51  Independent categorical variable found after C...
#
# [52 rows x 4 columns]

# %% [markdown]
# ### numerical data after scaling

# %%
num_scaled.head(5)
# Out:
#    MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0       -0.783843       -0.580074             -1.045645
# 1       -0.941334       -0.974398             -1.255508
# 2       -0.469311       -0.978171             -0.374082
# 3        0.525509        1.482105              1.178906
# 4       -0.937964       -0.993265             -1.255508
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0              -0.289834       -0.414232     -0.125819          -0.564829
# 1              -0.401835       -0.414232     -0.125819           0.029311
# 2              -0.401835       -0.414232     -0.125819           0.037078
# 3               0.153688       -0.414232     -0.125819           0.654518
# 4              -0.401835       -0.414232     -0.125819           0.044845
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0           -0.449982     -0.588732     -0.310138        -0.567148
# 1            0.030120     -0.632953     -0.373953        -0.659648
# 2            0.030120     -0.666120     -0.373953        -0.729024
# 3            0.234795      5.082715      0.328017         1.223762
# 4            0.025067     -0.666120     -0.373953        -0.729024
#
#    CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0          -0.367182      -0.256169      -0.107761      -0.723013
# 1          -0.367182      -0.256169      -0.691072      -0.723013
# 2          -0.367182      -0.256169      -0.688671      -0.714491
# 3           0.474745       0.855308       0.510956       9.795865
# 4          -0.367182      -0.256169      -0.691072      -0.723013
#
#    InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0     -0.491577       -0.312753          -0.472485            -0.570786
# 1     -0.491577       -0.817997          -0.720326            -0.635004
# 2     -0.491577       -0.853269          -0.691232            -0.654269
# 3      8.311225        4.431774           2.541478             3.179537
# 4     -0.491577       -0.865662          -0.731102            -0.654269
#
#    CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0            -0.020737         -0.276289         4.339230    0.382345
# 1            -0.020737         -0.329856         4.031488   -0.433489
# 2            -0.020737         -0.329856         4.236649   -0.433489
# 3            -0.020737          3.723433         4.134069    0.382345
# 4            -0.020737         -0.329856         3.518585    0.382345
#
#    ActiveSubs  Handsets  HandsetModels  CurrentEquipmentDays  RetentionCalls  \
# 0   -0.523532  0.146580       0.487141             -0.072301        4.784978
# 1   -0.523532  0.146580      -0.616471              4.462720       -0.175702
# 2   -0.523532 -0.604989      -0.616471              5.684756       -0.175702
# 3    0.956226  5.407560       2.694365              0.312561       -0.175702
# 4    0.956226  1.649717       1.590753              1.875814       -0.175702
#
#    RetentionOffersAccepted  ReferralsMadeBySubscriber  IncomeGroup  \
# 0                -0.127989                  -0.169323    -0.103552
# 1                -0.127989                  -0.169323     0.215218
# 2                -0.127989                  -0.169323     0.533989
# 3                -0.127989                  -0.169323     0.533989
# 4                -0.127989                  -0.169323     1.490301
#
#    AdjustmentsToCreditRating       Age
# 0                  -0.140245  1.587335
# 1                  -0.140245 -0.144763
# 2                  -0.140245 -1.381975
# 3                  -0.140245 -1.052052
# 4                   2.476643  0.597565

# %%
num_scaled.shape
# Out:
# (50679, 33)

# %%
cat_cols=df1.select_dtypes(include='object')

# %%
cat_cols.head(2)
# Out:
#   Churn ChildrenInHH HandsetRefurbished HandsetWebCapable TruckOwner RVOwner  \
# 0   Yes           No                 No               Yes         No      No
# 1   Yes          Yes                 No                No         No      No
#
#   Homeownership BuysViaMailOrder RespondsToMailOffers OptOutMailings  \
# 0         Known              Yes                  Yes             No
# 1         Known              Yes                  Yes             No
#
#   NonUSTravel OwnsComputer HasCreditCard NewCellphoneUser OwnsMotorcycle  \
# 0          No          Yes           Yes               No             No
# 1          No          Yes           Yes              Yes             No
#
#   MadeCallToRetentionTeam CreditRating PrizmCode    Occupation  \
# 0                     Yes         High  Suburban  Professional
# 1                      No       Medium  Suburban  Professional
#
#   New_maritalstatus
# 0                No
# 1               Yes

# %%
cat_cols.shape
# Out:
# (50679, 20)

# %%
df_final=pd.concat([num_scaled,cat_cols],axis=1)

# %%
df_final.head()
# Out:
#    MonthlyRevenue  MonthlyMinutes  TotalRecurringCharge  \
# 0       -0.783843       -0.580074             -1.045645
# 1       -0.941334       -0.974398             -1.255508
# 2       -0.469311       -0.978171             -0.374082
# 3        0.525509        1.482105              1.178906
# 4       -0.937964       -0.993265             -1.255508
#
#    DirectorAssistedCalls  OverageMinutes  RoamingCalls  PercChangeMinutes  \
# 0              -0.289834       -0.414232     -0.125819          -0.564829
# 1              -0.401835       -0.414232     -0.125819           0.029311
# 2              -0.401835       -0.414232     -0.125819           0.037078
# 3               0.153688       -0.414232     -0.125819           0.654518
# 4              -0.401835       -0.414232     -0.125819           0.044845
#
#    PercChangeRevenues  DroppedCalls  BlockedCalls  UnansweredCalls  \
# 0           -0.449982     -0.588732     -0.310138        -0.567148
# 1            0.030120     -0.632953     -0.373953        -0.659648
# 2            0.030120     -0.666120     -0.373953        -0.729024
# 3            0.234795      5.082715      0.328017         1.223762
# 4            0.025067     -0.666120     -0.373953        -0.729024
#
#    CustomerCareCalls  ThreewayCalls  ReceivedCalls  OutboundCalls  \
# 0          -0.367182      -0.256169      -0.107761      -0.723013
# 1          -0.367182      -0.256169      -0.691072      -0.723013
# 2          -0.367182      -0.256169      -0.688671      -0.714491
# 3           0.474745       0.855308       0.510956       9.795865
# 4          -0.367182      -0.256169      -0.691072      -0.723013
#
#    InboundCalls  PeakCallsInOut  OffPeakCallsInOut  DroppedBlockedCalls  \
# 0     -0.491577       -0.312753          -0.472485            -0.570786
# 1     -0.491577       -0.817997          -0.720326            -0.635004
# 2     -0.491577       -0.853269          -0.691232            -0.654269
# 3      8.311225        4.431774           2.541478             3.179537
# 4     -0.491577       -0.865662          -0.731102            -0.654269
#
#    CallForwardingCalls  CallWaitingCalls  MonthsInService  UniqueSubs  \
# 0            -0.020737         -0.276289         4.339230    0.382345
# 1            -0.020737         -0.329856         4.031488   -0.433489
# 2            -0.020737         -0.329856         4.236649   -0.433489
# 3            -0.020737          3.723433         4.134069    0.382345
# 4            -0.020737         -0.329856         3.518585    0.382345
#
#    ActiveSubs  Handsets  HandsetModels  CurrentEquipmentDays  RetentionCalls  \
# 0   -0.523532  0.146580       0.487141             -0.072301        4.784978
# 1   -0.523532  0.146580      -0.616471              4.462720       -0.175702
# 2   -0.523532 -0.604989      -0.616471              5.684756       -0.175702
# 3    0.956226  5.407560       2.694365              0.312561       -0.175702
# 4    0.956226  1.649717       1.590753              1.875814       -0.175702
#
#    RetentionOffersAccepted  ReferralsMadeBySubscriber  IncomeGroup  \
# 0                -0.127989                  -0.169323    -0.103552
# 1                -0.127989                  -0.169323     0.215218
# 2                -0.127989                  -0.169323     0.533989
# 3                -0.127989                  -0.169323     0.533989
# 4                -0.127989                  -0.169323     1.490301
#
#    AdjustmentsToCreditRating       Age Churn ChildrenInHH HandsetRefurbished  \
# 0                  -0.140245  1.587335   Yes           No                 No
# 1                  -0.140245 -0.144763   Yes          Yes                 No
# 2                  -0.140245 -1.381975    No          Yes                 No
# 3                  -0.140245 -1.052052    No           No                 No
# 4                   2.476643  0.597565   Yes           No                 No
#
#   HandsetWebCapable TruckOwner RVOwner Homeownership BuysViaMailOrder  \
# 0               Yes         No      No         Known              Yes
# 1                No         No      No         Known              Yes
# 2                No         No      No       Unknown               No
# 3               Yes         No      No         Known              Yes
# 4                No         No      No         Known              Yes
#
#   RespondsToMailOffers OptOutMailings NonUSTravel OwnsComputer HasCreditCard  \
# 0                  Yes             No          No          Yes           Yes
# 1                  Yes             No          No          Yes           Yes
# 2                   No             No          No           No           Yes
# 3                  Yes             No          No           No           Yes
# 4                  Yes             No          No          Yes           Yes
#
#   NewCellphoneUser OwnsMotorcycle MadeCallToRetentionTeam CreditRating  \
# 0               No             No                     Yes         High
# 1              Yes             No                      No       Medium
# 2              Yes             No                      No       Medium
# 3              Yes             No                      No       Medium
# 4               No             No                      No         High
#
#   PrizmCode    Occupation New_maritalstatus
# 0  Suburban  Professional                No
# 1  Suburban  Professional               Yes
# 2      Town        Crafts               Yes
# 3     Other         Other                No
# 4     Other  Professional               Yes

# %%
df_final.shape
# Out:
# (50679, 53)

# %% [markdown]
# ## VIF to check multicollinearity between the numerical variables.

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
# create an empty dataframe to store the VIF for each variable
  
vif=pd.DataFrame()
# calculate VIF using list comprehension 
# use for loop to access each variable 
# calculate VIF for each variable and create a column 'VIF_Factor' to store the values 
vif["VIF_Factor"] = [variance_inflation_factor(num_scaled.values, i) for i in range(num_scaled.shape[1])]

# create a column of variable names
vif["Features"] = num_scaled.columns

# sort the dataframe based on the values of VIF_Factor in descending order
# 'ascending = False' sorts the data in descending order
# 'reset_index' resets the index of the dataframe
# 'drop = True' drops the previous index
vif.sort_values('VIF_Factor', ascending = False).reset_index(drop = True)
# Out:
#     VIF_Factor                   Features
# 0   263.089483        DroppedBlockedCalls
# 1   133.129373               BlockedCalls
# 2    91.210629               DroppedCalls
# 3    11.198276             MonthlyRevenue
# 4     6.651223             OverageMinutes
# 5     6.217595             MonthlyMinutes
# 6     5.514426              HandsetModels
# 7     5.181104          OffPeakCallsInOut
# 8     4.951826                   Handsets
# 9     4.506253             PeakCallsInOut
# 10    4.261220              ReceivedCalls
# 11    4.122065       TotalRecurringCharge
# 12    3.557968              OutboundCalls
# 13    2.661700            MonthsInService
# 14    2.622790            UnansweredCalls
# 15    2.614363                 ActiveSubs
# 16    2.572323               InboundCalls
# 17    2.531890                 UniqueSubs
# 18    2.492452           CallWaitingCalls
# 19    2.481722       CurrentEquipmentDays
# 20    2.282738             RetentionCalls
# 21    2.272071    RetentionOffersAccepted
# 22    1.632257          PercChangeMinutes
# 23    1.620044         PercChangeRevenues
# 24    1.601234               RoamingCalls
# 25    1.344201          CustomerCareCalls
# 26    1.343533      DirectorAssistedCalls
# 27    1.188184              ThreewayCalls
# 28    1.075708                IncomeGroup
# 29    1.071277  AdjustmentsToCreditRating
# 30    1.045947                        Age
# 31    1.013083  ReferralsMadeBySubscriber
# 32    1.001862        CallForwardingCalls

# %% [markdown]
# Observation:
#   *  from above result we know that DroppedBlockedCalls  having more vif value.
#   *  dropping the DroppedBlockedCalls  variable and checking for the vif.

# %%
new_num_col=num_scaled.drop(columns=['DroppedBlockedCalls'])

# %%
# create an empty dataframe to store the VIF for each variable
 
vif=pd.DataFrame()
# calculate VIF using list comprehension 
# use for loop to access each variable 
# calculate VIF for each variable and create a column 'VIF_Factor' to store the values 
vif["VIF_Factor"] = [variance_inflation_factor(new_num_col.values, i) for i in range(new_num_col.shape[1])]

# create a column of variable names
vif["Features"] = new_num_col.columns

# sort the dataframe based on the values of VIF_Factor in descending order
# 'ascending = False' sorts the data in descending order
# 'reset_index' resets the index of the dataframe
# 'drop = True' drops the previous index
vif.sort_values('VIF_Factor', ascending = False).reset_index(drop = True)
# Out:
#     VIF_Factor                   Features
# 0    11.196540             MonthlyRevenue
# 1     6.651222             OverageMinutes
# 2     6.217398             MonthlyMinutes
# 3     5.514142              HandsetModels
# 4     5.179655          OffPeakCallsInOut
# 5     4.951826                   Handsets
# 6     4.504796             PeakCallsInOut
# 7     4.260479              ReceivedCalls
# 8     4.121842       TotalRecurringCharge
# 9     3.557107              OutboundCalls
# 10    2.661699            MonthsInService
# 11    2.621247            UnansweredCalls
# 12    2.614354                 ActiveSubs
# 13    2.572318               InboundCalls
# 14    2.531858                 UniqueSubs
# 15    2.492445           CallWaitingCalls
# 16    2.481684       CurrentEquipmentDays
# 17    2.282724             RetentionCalls
# 18    2.272069    RetentionOffersAccepted
# 19    1.832372               DroppedCalls
# 20    1.632102          PercChangeMinutes
# 21    1.620028         PercChangeRevenues
# 22    1.601111               RoamingCalls
# 23    1.343473      DirectorAssistedCalls
# 24    1.316644          CustomerCareCalls
# 25    1.204361               BlockedCalls
# 26    1.188054              ThreewayCalls
# 27    1.075698                IncomeGroup
# 28    1.071271  AdjustmentsToCreditRating
# 29    1.045943                        Age
# 30    1.013066  ReferralsMadeBySubscriber
# 31    1.001862        CallForwardingCalls

# %% [markdown]
# Observation :-
# * after dropping DroppedBlockedCalls variable ,we can see now all variables are having less vif value,no multicollinearity.

# %% [markdown]
# # New dataframe after cleaning

# %%
df_final.to_csv('data1.csv',sep=',')
